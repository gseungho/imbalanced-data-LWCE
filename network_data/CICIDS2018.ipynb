# %% [markdown]
# # CICIDS2018 Network Intrusion Detection — LWCE Loss Comparison
#
# PyTorch MLP on CICIDS2018 (15-class: BENIGN + attack types, day-based CSVs).
# Comparing 7 loss functions: `ce`, `wce`, `pwce`, `lwce`, `plwce`, `cb`, `focal`.

# %%
# !pip install -q torch torchvision optuna pandas openpyxl scikit-learn kagglehub

import os, sys, gc, json, warnings, importlib.util, glob
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Subset
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score)
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import optuna
from optuna.samplers import GridSampler

warnings.filterwarnings('ignore')

REPO_PATH = '/content/imbalanced-data-LWCE'
if not os.path.exists(REPO_PATH):
    print('Cloning...')
    # !git clone https://github.com/gseungho/imbalanced-data-LWCE.git {REPO_PATH}

get_clf_loss = None
try:
    spec = importlib.util.spec_from_file_location(
        'clf', f'{REPO_PATH}/image_classification/custom_losses.py'
    )
    clf_module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(clf_module)
    get_clf_loss = clf_module.get_clf_loss
    print('✓ Loss functions loaded!')
except Exception as e:
    print(f'Warning: {e}')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# Kaggle dataset ID: 'solarmainframe/ids-intrusion-csv'
# Alternative IDs to try if download fails:
#   'ernie55ernie/network-intrusion-detection'
#   'chethuhn/network-intrusion-dataset-2018'
# Check: https://www.kaggle.com/datasets  → search 'CICIDS 2018'

DATASET_NAME       = 'CICIDS2018'
BATCH_SIZE         = 512
FINAL_EPOCHS       = 50
PROXY_EPOCHS       = 10
PROXY_SUBSET_RATIO = 0.20
TARGET_TOTAL       = 300_000
BENIGN_MAX         = 100_000
RESULTS_DIR = '/content/gdrive/MyDrive/imbalanced-data-LWCE/network_data/results/CICIDS2018'
os.makedirs(RESULTS_DIR, exist_ok=True)
print(f'Results dir: {RESULTS_DIR}')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 12.5 MB/s eta 0:00:00
# Cloning...
# Cloning into '/content/imbalanced-data-LWCE'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (636/636), done.
# remote: Compressing objects: 100% (461/461), done.
# remote: Total 636 (delta 253), reused 453 (delta 151), pack-reused 0 (from 0)
# Receiving objects: 100% (636/636), 34.47 MiB | 13.74 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# ✓ Loss functions loaded!
# Device: cuda
# Results dir: /content/gdrive/MyDrive/imbalanced-data-LWCE/network_data/results/CICIDS2018

# %%
def _detect_files(path):
    all_files = sorted(glob.glob(f'{path}/**/*', recursive=True))
    all_files = [f for f in all_files if os.path.isfile(f)]
    print(f'All files found ({len(all_files)}):')
    for f in all_files[:30]:
        print(f'  {os.path.relpath(f, path)}  ({os.path.getsize(f):,} bytes)')
    if len(all_files) > 30:
        print(f'  ... and {len(all_files) - 30} more')
    csv_files     = sorted(glob.glob(f'{path}/**/*.csv',     recursive=True))
    parquet_files = sorted(glob.glob(f'{path}/**/*.parquet', recursive=True))
    return all_files, csv_files, parquet_files


def _detect_label_col(df, priority):
    for c in priority:
        if c in df.columns:
            return c
    col = df.columns[-1]
    print(f'Warning: using last column as label: {col!r}')
    return col


def _stratified_subset(df, label_col, target_total, benign_max):
    unique_labels = df[label_col].unique()
    normal_label  = next((l for l in unique_labels
                          if 'normal' in l.lower() or 'benign' in l.lower()), None)
    non_budget    = target_total - (benign_max if normal_label else 0)
    non_total     = (df[label_col] != normal_label).sum() if normal_label else len(df)
    idx_list = []
    for lbl in unique_labels:
        idx = df.index[df[label_col] == lbl].tolist()
        if normal_label and lbl == normal_label:
            take = min(len(idx), benign_max)
        else:
            prop = len(idx) / max(non_total, 1)
            take = max(50, min(len(idx), int(prop * non_budget)))
        idx_list.extend(np.random.choice(idx, min(take, len(idx)), replace=False).tolist())
    return df.loc[idx_list].reset_index(drop=True)


def make_loaders(X_tr, X_val, X_te, y_tr, y_val, y_te, batch_size):
    def ds(X, y):
        return TensorDataset(torch.tensor(X, dtype=torch.float32),
                             torch.tensor(y, dtype=torch.long))
    train_loader = DataLoader(ds(X_tr,  y_tr),  batch_size=batch_size, shuffle=True,  num_workers=0)
    val_loader   = DataLoader(ds(X_val, y_val), batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(ds(X_te,  y_te),  batch_size=batch_size, shuffle=False, num_workers=0)
    return train_loader, val_loader, test_loader


def _read_csv_chunked(f, rows_per_file):
    """파일 전체에 걸쳐 균등 샘플링 (공격 트래픽이 파일 후반부에 있는 경우 대응)."""
    sample_per_chunk = max(500, rows_per_file // 6)
    enc = 'utf-8'
    try:
        chunks = [chunk.sample(min(sample_per_chunk, len(chunk)), random_state=42)
                  for chunk in pd.read_csv(f, chunksize=100_000, encoding=enc, low_memory=False)]
    except UnicodeDecodeError:
        enc = 'latin-1'
        chunks = [chunk.sample(min(sample_per_chunk, len(chunk)), random_state=42)
                  for chunk in pd.read_csv(f, chunksize=100_000, encoding=enc, low_memory=False)]
    df_part = pd.concat(chunks, ignore_index=True)
    if len(df_part) > rows_per_file:
        df_part = df_part.sample(rows_per_file, random_state=42)
    return df_part


# Cell 1: Load & Preprocess CICIDS2018
import kagglehub

def load_cicids2018():
    print('Downloading CICIDS2018...')
    path = kagglehub.dataset_download('solarmainframe/ids-intrusion-csv')
    print(f'Dataset path: {path}')

    all_files, csv_files, _ = _detect_files(path)
    files = csv_files
    if not files:
        raise FileNotFoundError(f'No CSV files found. All files: {[os.path.basename(f) for f in all_files]}')

    # 파일 전체에서 균등 샘플링 (공격 트래픽은 파일 후반부에 집중)
    rows_per_file = max(5_000, (TARGET_TOTAL * 2) // len(files))
    print(f'\nLoading {len(files)} CSV files (~{rows_per_file:,} rows each, sampled throughout)...')
    dfs = []
    for f in files:
        df_part = _read_csv_chunked(f, rows_per_file)
        dfs.append(df_part)
        print(f'  {os.path.basename(f)}: {len(df_part):,} rows')
    df = pd.concat(dfs, axis=0, ignore_index=True)
    print(f'Total rows loaded: {len(df):,}')
    print(f'Columns: {df.columns.tolist()[:10]} ...')

    # CICIDS2018 uses 'Label' column (may have leading/trailing spaces)
    LABEL_PRIORITY = ['Label', 'label', 'Class', 'class',
                      'Attack_type', 'attack_type', 'category']
    label_col = _detect_label_col(df, LABEL_PRIORITY)
    print(f'\nUsing label column: {label_col!r}')
    df['label'] = df[label_col].astype(str).str.strip()

    # 헤더 행 제거 (컬럼명이 데이터로 포함된 경우)
    before_hdr = len(df)
    df = df[df['label'] != label_col].reset_index(drop=True)
    if len(df) < before_hdr:
        print(f'Removed {before_hdr - len(df):,} header-as-data rows')

    print(f'Unique labels ({df["label"].nunique()}): {sorted(df["label"].unique())}')

    # 헤더 오염으로 object 타입이 된 숫자 컬럼들을 다시 numeric으로 변환
    # (Timestamp 등 실제 문자열 컬럼은 errors='coerce'로 NaN 처리됨)
    feature_cols = [c for c in df.columns if c not in [label_col, 'label']]
    df[feature_cols] = df[feature_cols].apply(pd.to_numeric, errors='coerce')
    num_cols = df[feature_cols].select_dtypes(include=[np.number]).columns.tolist()

    # inf → NaN 후 mostly-inf 컬럼 제거 (Flow Bytes/s, Flow Packets/s 등 ratio 피처)
    df[num_cols] = df[num_cols].replace([np.inf, -np.inf], np.nan)
    inf_fracs = df[num_cols].isna().mean()
    drop_cols = inf_fracs[inf_fracs > 0.30].index.tolist()
    if drop_cols:
        print(f'Dropping {len(drop_cols)} mostly-inf columns: {drop_cols}')
        num_cols = [c for c in num_cols if c not in drop_cols]

    # 남은 NaN은 컬럼 median으로 채움
    col_medians = df[num_cols].median()
    df[num_cols] = df[num_cols].fillna(col_medians)
    print(f'Numeric features (after dropping inf cols): {len(num_cols)}')

    df_sub = _stratified_subset(df, 'label', TARGET_TOTAL, BENIGN_MAX)
    del df; gc.collect()
    print(f'Subset size: {len(df_sub):,}')

    le = LabelEncoder()
    df_sub['class'] = le.fit_transform(df_sub['label'])
    class_names_enc = le.classes_.tolist()
    num_cls         = len(class_names_enc)
    print(f'Classes ({num_cls}): {class_names_enc}')

    X = df_sub[num_cols].values.astype(np.float32)
    y = df_sub['class'].values.astype(np.int64)

    X_tr, X_tmp, y_tr, y_tmp = train_test_split(
        X, y, test_size=0.30, stratify=y, random_state=42
    )
    X_val, X_te, y_val, y_te = train_test_split(
        X_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=42
    )
    scaler = StandardScaler()
    X_tr  = scaler.fit_transform(X_tr)
    X_val = scaler.transform(X_val)
    X_te  = scaler.transform(X_te)

    class_counts = [int((y_tr == i).sum()) for i in range(num_cls)]
    input_dim    = X_tr.shape[1]
    print(f'\n✓ Loaded: Train={len(X_tr):,}, Val={len(X_val):,}, Test={len(X_te):,}')
    print(f'Input dim: {input_dim}')
    print('\nClass distribution (train):')
    for i, (name, cnt) in enumerate(zip(class_names_enc, class_counts)):
        pct = cnt / sum(class_counts) * 100
        print(f'  {i:2d} {name:35s}: {cnt:6,d} ({pct:.2f}%)')
    ir = max(class_counts) / max(min(c for c in class_counts if c > 0), 1)
    print(f'Imbalance ratio: {ir:.0f}:1')
    return (X_tr, X_val, X_te, y_tr, y_val, y_te,
            class_counts, input_dim, class_names_enc, num_cls)


(X_tr, X_val, X_te, y_tr, y_val, y_te,
 class_counts, INPUT_DIM, CLASS_NAMES, NUM_CLASSES) = load_cicids2018()
train_loader, val_loader, test_loader = make_loaders(
    X_tr, X_val, X_te, y_tr, y_val, y_te, BATCH_SIZE
)
# Out:
# Downloading CICIDS2018...
# Using Colab cache for faster access to the 'ids-intrusion-csv' dataset.
# Dataset path: /kaggle/input/ids-intrusion-csv
# All files found (10):
#   02-14-2018.csv  (358,223,333 bytes)
#   02-15-2018.csv  (375,945,899 bytes)
#   02-16-2018.csv  (333,723,605 bytes)
#   02-20-2018.csv  (4,054,925,350 bytes)
#   02-21-2018.csv  (328,893,673 bytes)
#   02-22-2018.csv  (382,636,202 bytes)
#   02-23-2018.csv  (382,840,456 bytes)
#   02-28-2018.csv  (209,249,758 bytes)
#   03-01-2018.csv  (107,842,858 bytes)
#   03-02-2018.csv  (352,368,373 bytes)
#
# Loading 10 CSV files (~60,000 rows each, sampled throughout)...
#   02-14-2018.csv: 60,000 rows
#   02-15-2018.csv: 60,000 rows
#   02-16-2018.csv: 60,000 rows
#   02-20-2018.csv: 60,000 rows
#   02-21-2018.csv: 60,000 rows
#   02-22-2018.csv: 60,000 rows
#   02-23-2018.csv: 60,000 rows
#   02-28-2018.csv: 60,000 rows
#   03-01-2018.csv: 40,000 rows
#   03-02-2018.csv: 60,000 rows
# Total rows loaded: 580,000
# Columns: ['Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min'] ...
#
# Using label column: 'Label'
# Removed 9 header-as-data rows
# Unique labels (15): ['Benign', 'Bot', 'Brute Force -Web', 'Brute Force -XSS', 'DDOS attack-HOIC', 'DDOS attack-LOIC-UDP', 'DDoS attacks-LOIC-HTTP', 'DoS attacks-GoldenEye', 'DoS attacks-Hulk', 'DoS attacks-SlowHTTPTest', 'DoS attacks-Slowloris', 'FTP-BruteForce', 'Infilteration', 'SQL Injection', 'SSH-Bruteforce']
# Dropping 5 mostly-inf columns: ['Timestamp', 'Flow ID', 'Src IP', 'Src Port', 'Dst IP']
# Numeric features (after dropping inf cols): 78
# Subset size: 237,517
# Classes (15): ['Benign', 'Bot', 'Brute Force -Web', 'Brute Force -XSS', 'DDOS attack-HOIC', 'DDOS attack-LOIC-UDP', 'DDoS attacks-LOIC-HTTP', 'DoS attacks-GoldenEye', 'DoS attacks-Hulk', 'DoS attacks-SlowHTTPTest', 'DoS attacks-Slowloris', 'FTP-BruteForce', 'Infilteration', 'SQL Injection', 'SSH-Bruteforce']
#
# ✓ Loaded: Train=166,261, Val=35,628, Test=35,628
# Input dim: 78
#
# Class distribution (train):
#    0 Benign                             : 69,999 (42.10%)
#    1 Bot                                : 10,927 (6.57%)
#    2 Brute Force -Web                   :     17 (0.01%)
#    3 Brute Force -XSS                   :     14 (0.01%)
#    4 DDOS attack-HOIC                   : 27,223 (16.37%)
#    5 DDOS attack-LOIC-UDP               :     73 (0.04%)
#    6 DDoS attacks-LOIC-HTTP             :  2,950 (1.77%)
#    7 DoS attacks-GoldenEye              :  1,564 (0.94%)
#    8 DoS attacks-Hulk                   : 17,638 (10.61%)
#    9 DoS attacks-SlowHTTPTest           :  7,250 (4.36%)
#   10 DoS attacks-Slowloris              :    430 (0.26%)
#   11 FTP-BruteForce                     :  7,332 (4.41%)
#   12 Infilteration                      : 13,599 (8.18%)
#   13 SQL Injection                      :      4 (0.00%)
#   14 SSH-Bruteforce                     :  7,241 (4.36%)
# Imbalance ratio: 17500:1

# %%
# Cell 2: Class Distribution Visualization
def visualize_distribution(class_counts, class_names, title, save_path):
    counts = np.array(class_counts)
    order  = np.argsort(counts)[::-1]
    q1, q3 = np.percentile(counts, [33, 66])
    colors = ['#2ecc71' if c >= q3 else '#f39c12' if c >= q1 else '#e74c3c'
              for c in counts[order]]
    fig, ax = plt.subplots(figsize=(max(12, len(class_names)), 4))
    ax.bar(range(len(class_names)), counts[order], color=colors, alpha=0.85)
    ax.set_xticks(range(len(class_names)))
    ax.set_xticklabels([class_names[i] for i in order],
                       rotation=45, ha='right', fontsize=8)
    ax.set_yscale('log')
    ax.set_ylabel('# Training Samples (log scale)')
    ax.set_title(f'{title}  —  Green: Head / Orange: Mid / Red: Tail')
    ax.grid(True, alpha=0.3, axis='y')
    for i, c in enumerate(counts[order]):
        ax.text(i, c * 1.5, f'{c:,}', ha='center', va='bottom', fontsize=7)
    plt.tight_layout()
    plt.savefig(save_path, dpi=100, bbox_inches='tight')
    plt.show()
    q1_val, q3_val = np.percentile(counts, [33, 66])
    head = sum(1 for c in counts if c >= q3_val)
    mid  = sum(1 for c in counts if q1_val <= c < q3_val)
    tail = sum(1 for c in counts if c < q1_val)
    print(f'Head (≥{q3_val:.0f}): {head} classes')
    print(f'Mid  ({q1_val:.0f}–{q3_val:.0f}): {mid} classes')
    print(f'Tail (<{q1_val:.0f}): {tail} classes')

visualize_distribution(
    class_counts, CLASS_NAMES,
    f'{DATASET_NAME} Class Distribution',
    f'{RESULTS_DIR}/class_distribution.png'
)
# Out:
# Head (≥8195): 5 classes
# Mid  (1133–8195): 5 classes
# Tail (<1133): 5 classes

# %%
# Cell 3: MLP Model + Evaluation Functions

class MLP(nn.Module):
    def __init__(self, input_dim, num_classes,
                 hidden_dims=(256, 128, 64), dropout=0.3):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_dims:
            layers += [nn.Linear(prev, h), nn.BatchNorm1d(h),
                       nn.ReLU(), nn.Dropout(dropout)]
            prev = h
        layers.append(nn.Linear(prev, num_classes))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)


def build_mlp():
    return MLP(INPUT_DIM, NUM_CLASSES).to(DEVICE)


def compute_metrics(model, loader, class_counts):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for X_b, y_b in loader:
            preds = model(X_b.to(DEVICE)).argmax(dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_b.numpy())
    y_true = np.array(all_labels)
    y_pred = np.array(all_preds)
    labels = list(range(NUM_CLASSES))
    per_f1 = f1_score(y_true, y_pred, average=None, labels=labels, zero_division=0)
    counts = np.array(class_counts)
    q1, q3 = np.percentile(counts, [33, 66])
    head_idx = [i for i in range(NUM_CLASSES) if counts[i] >= q3]
    mid_idx  = [i for i in range(NUM_CLASSES) if q1 <= counts[i] < q3]
    tail_idx = [i for i in range(NUM_CLASSES) if counts[i] < q1]
    return {
        'Accuracy':          float(accuracy_score(y_true, y_pred)),
        'Balanced_Accuracy': float(balanced_accuracy_score(y_true, y_pred)),
        'F1_Macro':          float(f1_score(y_true, y_pred, average='macro',    zero_division=0)),
        'F1_Weighted':       float(f1_score(y_true, y_pred, average='weighted', zero_division=0)),
        'Per_Class_F1':      per_f1.tolist(),
        'Head_F1': float(per_f1[head_idx].mean()) if head_idx else 0.0,
        'Mid_F1':  float(per_f1[mid_idx].mean())  if mid_idx  else 0.0,
        'Tail_F1': float(per_f1[tail_idx].mean()) if tail_idx else 0.0,
    }

print('✓ MLP and evaluation functions defined')
# Out:
# ✓ MLP and evaluation functions defined

# %%
# Cell 4: train_model() — definition only, not executed here

def train_model(loss_name, class_counts, tr_loader, val_loader,
                alpha=1.0, gamma=2.0, epochs=FINAL_EPOCHS):
    model = build_mlp()
    if get_clf_loss is not None:
        criterion = get_clf_loss(loss_name, class_counts, alpha=alpha, gamma=gamma)
    else:
        criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', patience=5, factor=0.5, min_lr=1e-6
    )
    history       = {'train_loss': [], 'val_F1_Macro': []}
    best_F1_Macro = 0.0
    best_state    = None
    print(f"\n{'='*50}\nTraining {loss_name.upper()} (α={alpha:.2f}, γ={gamma:.2f})\n{'='*50}")
    for epoch in range(epochs):
        model.train()
        epoch_loss, n_batches = 0.0, 0
        for X_b, y_b in tr_loader:
            X_b, y_b = X_b.to(DEVICE), y_b.to(DEVICE)
            logits   = model(X_b)
            loss     = criterion(logits, y_b)
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            epoch_loss += loss.item()
            n_batches  += 1
        avg_loss = epoch_loss / max(n_batches, 1)
        history['train_loss'].append(avg_loss)
        metrics  = compute_metrics(model, val_loader, class_counts)
        f1_macro = metrics['F1_Macro']
        history['val_F1_Macro'].append(f1_macro)
        scheduler.step(f1_macro)
        if f1_macro > best_F1_Macro:
            best_F1_Macro = f1_macro
            best_state    = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        if (epoch + 1) % 10 == 0 or epoch == epochs - 1:
            print(f'Epoch {epoch+1:2d}/{epochs} | Loss: {avg_loss:.4f} | F1-Macro: {f1_macro:.4f}')
    if best_state is not None:
        model.load_state_dict({k: v.to(DEVICE) for k, v in best_state.items()})
    print(f'✓ {loss_name.upper()} best F1-Macro: {best_F1_Macro:.4f}')
    return model, history, best_F1_Macro

print('✓ train_model defined (not executed yet)')
# Out:
# ✓ train_model defined (not executed yet)

# %%
# Cell 5: Optuna Hyperparameter Search
optuna.logging.set_verbosity(optuna.logging.WARNING)
os.environ['TQDM_DISABLE'] = '1'

def _make_proxy_loader(ratio=PROXY_SUBSET_RATIO):
    n   = int(len(train_loader.dataset) * ratio)
    idx = np.random.choice(len(train_loader.dataset), n, replace=False)
    return DataLoader(Subset(train_loader.dataset, idx),
                     batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

def _cleanup(model=None):
    if model is not None:
        del model
    gc.collect()
    torch.cuda.empty_cache()

print(f'Optuna search (proxy: {PROXY_EPOCHS} epochs, {PROXY_SUBSET_RATIO*100:.0f}% subset)\n')
optuna_best  = {}
proxy_loader = _make_proxy_loader()

N_PWCE = 20
study_pwce = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'alpha': np.linspace(0.5, 5.0, N_PWCE).tolist()})
)
def obj_pwce(trial):
    alpha = trial.suggest_float('alpha', 0.5, 5.0)
    model, _, score = train_model('pwce', class_counts, proxy_loader, val_loader,
                                  alpha=alpha, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_pwce.optimize(obj_pwce, n_trials=N_PWCE)
best_pwce = study_pwce.best_params
optuna_best['pwce'] = best_pwce
print(f'✓ PWCE  best: alpha={best_pwce["alpha"]:.2f}  (F1-Macro={study_pwce.best_value:.4f})')

N_PLWCE = 20
study_plwce = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'alpha': np.linspace(1.0, 10.0, N_PLWCE).tolist()})
)
def obj_plwce(trial):
    alpha = trial.suggest_float('alpha', 1.0, 10.0)
    model, _, score = train_model('plwce', class_counts, proxy_loader, val_loader,
                                  alpha=alpha, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_plwce.optimize(obj_plwce, n_trials=N_PLWCE)
best_plwce = study_plwce.best_params
optuna_best['plwce'] = best_plwce
print(f'✓ PLWCE best: alpha={best_plwce["alpha"]:.2f}  (F1-Macro={study_plwce.best_value:.4f})')

N_FOCAL = 20
study_focal = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'gamma': np.linspace(0.5, 5.0, N_FOCAL).tolist()})
)
def obj_focal(trial):
    gamma = trial.suggest_float('gamma', 0.5, 5.0)
    model, _, score = train_model('focal', class_counts, proxy_loader, val_loader,
                                  gamma=gamma, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_focal.optimize(obj_focal, n_trials=N_FOCAL)
best_focal = study_focal.best_params
optuna_best['focal'] = best_focal
print(f'✓ FOCAL best: gamma={best_focal["gamma"]:.2f}  (F1-Macro={study_focal.best_value:.4f})')

print(f'\nOptuna Results:\n{json.dumps(optuna_best, indent=2)}')
# Out:
# Optuna search (proxy: 10 epochs, 20% subset)
#
#
# ==================================================
# Training PWCE (α=4.76, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0766 | F1-Macro: 0.1680
# ✓ PWCE best F1-Macro: 0.1692
#
# ==================================================
# Training PWCE (α=0.74, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3511 | F1-Macro: 0.7017
# ✓ PWCE best F1-Macro: 0.7190
#
# ==================================================
# Training PWCE (α=5.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0774 | F1-Macro: 0.2070
# ✓ PWCE best F1-Macro: 0.2070
#
# ==================================================
# Training PWCE (α=2.39, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2509 | F1-Macro: 0.4043
# ✓ PWCE best F1-Macro: 0.4764
#
# ==================================================
# Training PWCE (α=2.87, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.1403 | F1-Macro: 0.2899
# ✓ PWCE best F1-Macro: 0.2899
#
# ==================================================
# Training PWCE (α=4.53, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0753 | F1-Macro: 0.2103
# ✓ PWCE best F1-Macro: 0.2103
#
# ==================================================
# Training PWCE (α=1.92, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2511 | F1-Macro: 0.5622
# ✓ PWCE best F1-Macro: 0.6018
#
# ==================================================
# Training PWCE (α=3.58, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0731 | F1-Macro: 0.2088
# ✓ PWCE best F1-Macro: 0.2476
#
# ==================================================
# Training PWCE (α=1.45, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2929 | F1-Macro: 0.6690
# ✓ PWCE best F1-Macro: 0.6690
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4228 | F1-Macro: 0.6876
# ✓ PWCE best F1-Macro: 0.7034
#
# ==================================================
# Training PWCE (α=1.68, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2777 | F1-Macro: 0.6237
# ✓ PWCE best F1-Macro: 0.6237
#
# ==================================================
# Training PWCE (α=3.82, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.1664 | F1-Macro: 0.2057
# ✓ PWCE best F1-Macro: 0.2196
#
# ==================================================
# Training PWCE (α=2.63, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.1679 | F1-Macro: 0.4566
# ✓ PWCE best F1-Macro: 0.4566
#
# ==================================================
# Training PWCE (α=2.16, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2564 | F1-Macro: 0.5302
# ✓ PWCE best F1-Macro: 0.5584
#
# ==================================================
# Training PWCE (α=4.29, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0780 | F1-Macro: 0.1771
# ✓ PWCE best F1-Macro: 0.1924
#
# ==================================================
# Training PWCE (α=3.11, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.1410 | F1-Macro: 0.2575
# ✓ PWCE best F1-Macro: 0.2575
#
# ==================================================
# Training PWCE (α=1.21, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3695 | F1-Macro: 0.6981
# ✓ PWCE best F1-Macro: 0.6986
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3097 | F1-Macro: 0.7045
# ✓ PWCE best F1-Macro: 0.7384
#
# ==================================================
# Training PWCE (α=4.05, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0754 | F1-Macro: 0.2163
# ✓ PWCE best F1-Macro: 0.2193
#
# ==================================================
# Training PWCE (α=3.34, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0999 | F1-Macro: 0.2273
# ✓ PWCE best F1-Macro: 0.2273
# ✓ PWCE  best: alpha=0.50  (F1-Macro=0.7384)
#
# ==================================================
# Training PLWCE (α=9.53, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4148 | F1-Macro: 0.7608
# ✓ PLWCE best F1-Macro: 0.7608
#
# ==================================================
# Training PLWCE (α=1.47, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2702 | F1-Macro: 0.6938
# ✓ PLWCE best F1-Macro: 0.7015
#
# ==================================================
# Training PLWCE (α=10.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4034 | F1-Macro: 0.6742
# ✓ PLWCE best F1-Macro: 0.6828
#
# ==================================================
# Training PLWCE (α=4.79, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4206 | F1-Macro: 0.7172
# ✓ PLWCE best F1-Macro: 0.7315
#
# ==================================================
# Training PLWCE (α=5.74, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4612 | F1-Macro: 0.7069
# ✓ PLWCE best F1-Macro: 0.7424
#
# ==================================================
# Training PLWCE (α=9.05, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4509 | F1-Macro: 0.6918
# ✓ PLWCE best F1-Macro: 0.7275
#
# ==================================================
# Training PLWCE (α=3.84, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3283 | F1-Macro: 0.7119
# ✓ PLWCE best F1-Macro: 0.7397
#
# ==================================================
# Training PLWCE (α=7.16, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.6041 | F1-Macro: 0.6946
# ✓ PLWCE best F1-Macro: 0.7316
#
# ==================================================
# Training PLWCE (α=2.89, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2942 | F1-Macro: 0.7672
# ✓ PLWCE best F1-Macro: 0.7672
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2765 | F1-Macro: 0.7299
# ✓ PLWCE best F1-Macro: 0.7979
#
# ==================================================
# Training PLWCE (α=3.37, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3188 | F1-Macro: 0.7110
# ✓ PLWCE best F1-Macro: 0.7449
#
# ==================================================
# Training PLWCE (α=7.63, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4838 | F1-Macro: 0.7415
# ✓ PLWCE best F1-Macro: 0.7702
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4322 | F1-Macro: 0.7178
# ✓ PLWCE best F1-Macro: 0.7265
#
# ==================================================
# Training PLWCE (α=4.32, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3553 | F1-Macro: 0.7029
# ✓ PLWCE best F1-Macro: 0.7323
#
# ==================================================
# Training PLWCE (α=8.58, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4808 | F1-Macro: 0.6915
# ✓ PLWCE best F1-Macro: 0.7060
#
# ==================================================
# Training PLWCE (α=6.21, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.5156 | F1-Macro: 0.7077
# ✓ PLWCE best F1-Macro: 0.7288
#
# ==================================================
# Training PLWCE (α=2.42, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2884 | F1-Macro: 0.7143
# ✓ PLWCE best F1-Macro: 0.7443
#
# ==================================================
# Training PLWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2617 | F1-Macro: 0.7006
# ✓ PLWCE best F1-Macro: 0.7006
#
# ==================================================
# Training PLWCE (α=8.11, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.5303 | F1-Macro: 0.6942
# ✓ PLWCE best F1-Macro: 0.7049
#
# ==================================================
# Training PLWCE (α=6.68, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.5328 | F1-Macro: 0.7082
# ✓ PLWCE best F1-Macro: 0.7385
# ✓ PLWCE best: alpha=1.95  (F1-Macro=0.7979)
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.76)
# ==================================================
# Epoch 10/10 | Loss: 0.0186 | F1-Macro: 0.6878
# ✓ FOCAL best F1-Macro: 0.6912
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.74)
# ==================================================
# Epoch 10/10 | Loss: 0.1543 | F1-Macro: 0.6883
# ✓ FOCAL best F1-Macro: 0.6883
#
# ==================================================
# Training FOCAL (α=1.00, γ=5.00)
# ==================================================
# Epoch 10/10 | Loss: 0.0175 | F1-Macro: 0.6857
# ✓ FOCAL best F1-Macro: 0.6911
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.39)
# ==================================================
# Epoch 10/10 | Loss: 0.0591 | F1-Macro: 0.6853
# ✓ FOCAL best F1-Macro: 0.6885
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.87)
# ==================================================
# Epoch 10/10 | Loss: 0.0455 | F1-Macro: 0.6969
# ✓ FOCAL best F1-Macro: 0.6969
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.53)
# ==================================================
# Epoch 10/10 | Loss: 0.0214 | F1-Macro: 0.6872
# ✓ FOCAL best F1-Macro: 0.6872
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.92)
# ==================================================
# Epoch 10/10 | Loss: 0.0775 | F1-Macro: 0.6907
# ✓ FOCAL best F1-Macro: 0.6907
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.58)
# ==================================================
# Epoch 10/10 | Loss: 0.0328 | F1-Macro: 0.6916
# ✓ FOCAL best F1-Macro: 0.6916
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.45)
# ==================================================
# Epoch 10/10 | Loss: 0.1021 | F1-Macro: 0.6949
# ✓ FOCAL best F1-Macro: 0.6949
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.97)
# ==================================================
# Epoch 10/10 | Loss: 0.1350 | F1-Macro: 0.6937
# ✓ FOCAL best F1-Macro: 0.6937
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.68)
# ==================================================
# Epoch 10/10 | Loss: 0.0869 | F1-Macro: 0.6925
# ✓ FOCAL best F1-Macro: 0.6944
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.82)
# ==================================================
# Epoch 10/10 | Loss: 0.0288 | F1-Macro: 0.6906
# ✓ FOCAL best F1-Macro: 0.6909
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.63)
# ==================================================
# Epoch 10/10 | Loss: 0.0526 | F1-Macro: 0.6893
# ✓ FOCAL best F1-Macro: 0.6943
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/10 | Loss: 0.0681 | F1-Macro: 0.6980
# ✓ FOCAL best F1-Macro: 0.6980
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.29)
# ==================================================
# Epoch 10/10 | Loss: 0.0231 | F1-Macro: 0.6548
# ✓ FOCAL best F1-Macro: 0.6916
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/10 | Loss: 0.0402 | F1-Macro: 0.6928
# ✓ FOCAL best F1-Macro: 0.6928
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.21)
# ==================================================
# Epoch 10/10 | Loss: 0.1158 | F1-Macro: 0.6956
# ✓ FOCAL best F1-Macro: 0.6956
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.50)
# ==================================================
# Epoch 10/10 | Loss: 0.1798 | F1-Macro: 0.6829
# ✓ FOCAL best F1-Macro: 0.6978
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.05)
# ==================================================
# Epoch 10/10 | Loss: 0.0264 | F1-Macro: 0.6900
# ✓ FOCAL best F1-Macro: 0.6900
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.34)
# ==================================================
# Epoch 10/10 | Loss: 0.0359 | F1-Macro: 0.6890
# ✓ FOCAL best F1-Macro: 0.6924
# ✓ FOCAL best: gamma=2.16  (F1-Macro=0.6980)
#
# Optuna Results:
# {
#   "pwce": {
#     "alpha": 0.5
#   },
#   "plwce": {
#     "alpha": 1.9473684210526314
#   },
#   "focal": {
#     "gamma": 2.1578947368421053
#   }
# }

# %%
# Cell 6: Full Experiment (N_SEEDS seeds)
import random

N_SEEDS       = 5
LOSS_CONFIGS  = ['ce', 'wce', 'pwce', 'lwce', 'plwce', 'cb', 'focal']
seed_results   = {ln: [] for ln in LOSS_CONFIGS}
seed_histories = {ln: [] for ln in LOSS_CONFIGS}

print(f"\n{'='*60}")
print(f'FULL EXPERIMENT: {FINAL_EPOCHS} epochs × {len(LOSS_CONFIGS)} losses × {N_SEEDS} seeds')
print(f"{'='*60}")

for seed in range(N_SEEDS):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    print(f"\n{'─'*25}  Seed {seed}  {'─'*25}")
    for loss_name in LOSS_CONFIGS:
        alpha = optuna_best.get(loss_name, {}).get('alpha', 1.0)
        gamma = optuna_best.get('focal', {}).get('gamma', 2.0) if loss_name == 'focal' else 2.0
        model, history, _ = train_model(
            loss_name, class_counts, train_loader, val_loader,
            alpha=alpha, gamma=gamma, epochs=FINAL_EPOCHS
        )
        metrics = compute_metrics(model, test_loader, class_counts)
        seed_results[loss_name].append(metrics)
        seed_histories[loss_name].append(history)
        _cleanup(model)

print(f"\n{'='*60}")
print('✓ Full experiment completed!')
print(f"{'='*60}")
# Out:
# ============================================================
# FULL EXPERIMENT: 50 epochs × 7 losses × 5 seeds
# ============================================================
#
# ─────────────────────────  Seed 0  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2264 | F1-Macro: 0.7024
# Epoch 20/50 | Loss: 0.2198 | F1-Macro: 0.7104
# Epoch 30/50 | Loss: 0.2170 | F1-Macro: 0.7063
# Epoch 40/50 | Loss: 0.2151 | F1-Macro: 0.7067
# Epoch 50/50 | Loss: 0.2139 | F1-Macro: 0.7110
# ✓ CE best F1-Macro: 0.7110
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3367 | F1-Macro: 0.7305
# Epoch 20/50 | Loss: 0.2997 | F1-Macro: 0.7726
# Epoch 30/50 | Loss: 0.2632 | F1-Macro: 0.7733
# Epoch 40/50 | Loss: 0.2688 | F1-Macro: 0.7712
# Epoch 50/50 | Loss: 0.2502 | F1-Macro: 0.7768
# ✓ WCE best F1-Macro: 0.7922
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2683 | F1-Macro: 0.7928
# Epoch 20/50 | Loss: 0.2464 | F1-Macro: 0.7921
# Epoch 30/50 | Loss: 0.2436 | F1-Macro: 0.7891
# Epoch 40/50 | Loss: 0.2406 | F1-Macro: 0.7912
# Epoch 50/50 | Loss: 0.2437 | F1-Macro: 0.7911
# ✓ PWCE best F1-Macro: 0.8078
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2374 | F1-Macro: 0.7453
# Epoch 20/50 | Loss: 0.2289 | F1-Macro: 0.8174
# Epoch 30/50 | Loss: 0.2273 | F1-Macro: 0.8105
# Epoch 40/50 | Loss: 0.2245 | F1-Macro: 0.8243
# Epoch 50/50 | Loss: 0.2226 | F1-Macro: 0.8242
# ✓ LWCE best F1-Macro: 0.8304
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2496 | F1-Macro: 0.7885
# Epoch 20/50 | Loss: 0.2431 | F1-Macro: 0.7921
# Epoch 30/50 | Loss: 0.2336 | F1-Macro: 0.8080
# Epoch 40/50 | Loss: 0.2306 | F1-Macro: 0.8083
# Epoch 50/50 | Loss: 0.2300 | F1-Macro: 0.8084
# ✓ PLWCE best F1-Macro: 0.8148
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3525 | F1-Macro: 0.7741
# Epoch 20/50 | Loss: 0.2963 | F1-Macro: 0.7865
# Epoch 30/50 | Loss: 0.2861 | F1-Macro: 0.7898
# Epoch 40/50 | Loss: 0.2786 | F1-Macro: 0.7853
# Epoch 50/50 | Loss: 0.2757 | F1-Macro: 0.7918
# ✓ CB best F1-Macro: 0.8051
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/50 | Loss: 0.0582 | F1-Macro: 0.7020
# Epoch 20/50 | Loss: 0.0571 | F1-Macro: 0.7466
# Epoch 30/50 | Loss: 0.0544 | F1-Macro: 0.7420
# Epoch 40/50 | Loss: 0.0528 | F1-Macro: 0.7459
# Epoch 50/50 | Loss: 0.0521 | F1-Macro: 0.7416
# ✓ FOCAL best F1-Macro: 0.8149
#
# ─────────────────────────  Seed 1  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2266 | F1-Macro: 0.7024
# Epoch 20/50 | Loss: 0.2203 | F1-Macro: 0.7105
# Epoch 30/50 | Loss: 0.2166 | F1-Macro: 0.7042
# Epoch 40/50 | Loss: 0.2148 | F1-Macro: 0.7103
# Epoch 50/50 | Loss: 0.2141 | F1-Macro: 0.7039
# ✓ CE best F1-Macro: 0.7106
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3189 | F1-Macro: 0.7859
# Epoch 20/50 | Loss: 0.2756 | F1-Macro: 0.7617
# Epoch 30/50 | Loss: 0.2706 | F1-Macro: 0.7584
# Epoch 40/50 | Loss: 0.2651 | F1-Macro: 0.7646
# Epoch 50/50 | Loss: 0.2813 | F1-Macro: 0.7642
# ✓ WCE best F1-Macro: 0.7995
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2673 | F1-Macro: 0.7852
# Epoch 20/50 | Loss: 0.2489 | F1-Macro: 0.7899
# Epoch 30/50 | Loss: 0.2447 | F1-Macro: 0.7931
# Epoch 40/50 | Loss: 0.2421 | F1-Macro: 0.7947
# Epoch 50/50 | Loss: 0.2416 | F1-Macro: 0.7953
# ✓ PWCE best F1-Macro: 0.8067
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2369 | F1-Macro: 0.7616
# Epoch 20/50 | Loss: 0.2326 | F1-Macro: 0.8093
# Epoch 30/50 | Loss: 0.2270 | F1-Macro: 0.8154
# Epoch 40/50 | Loss: 0.2246 | F1-Macro: 0.8290
# Epoch 50/50 | Loss: 0.2223 | F1-Macro: 0.8308
# ✓ LWCE best F1-Macro: 0.8308
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2509 | F1-Macro: 0.7738
# Epoch 20/50 | Loss: 0.2433 | F1-Macro: 0.7934
# Epoch 30/50 | Loss: 0.2361 | F1-Macro: 0.7993
# Epoch 40/50 | Loss: 0.2314 | F1-Macro: 0.7954
# Epoch 50/50 | Loss: 0.2300 | F1-Macro: 0.8064
# ✓ PLWCE best F1-Macro: 0.8148
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3443 | F1-Macro: 0.7955
# Epoch 20/50 | Loss: 0.3140 | F1-Macro: 0.7864
# Epoch 30/50 | Loss: 0.2962 | F1-Macro: 0.7859
# Epoch 40/50 | Loss: 0.2818 | F1-Macro: 0.7824
# Epoch 50/50 | Loss: 0.2731 | F1-Macro: 0.7887
# ✓ CB best F1-Macro: 0.7955
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/50 | Loss: 0.0583 | F1-Macro: 0.7082
# Epoch 20/50 | Loss: 0.0570 | F1-Macro: 0.7460
# Epoch 30/50 | Loss: 0.0545 | F1-Macro: 0.7420
# Epoch 40/50 | Loss: 0.0531 | F1-Macro: 0.8107
# Epoch 50/50 | Loss: 0.0530 | F1-Macro: 0.7466
# ✓ FOCAL best F1-Macro: 0.8168
#
# ─────────────────────────  Seed 2  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2257 | F1-Macro: 0.7015
# Epoch 20/50 | Loss: 0.2205 | F1-Macro: 0.7046
# Epoch 30/50 | Loss: 0.2175 | F1-Macro: 0.7099
# Epoch 40/50 | Loss: 0.2151 | F1-Macro: 0.7487
# Epoch 50/50 | Loss: 0.2138 | F1-Macro: 0.7492
# ✓ CE best F1-Macro: 0.7570
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3169 | F1-Macro: 0.7546
# Epoch 20/50 | Loss: 0.2862 | F1-Macro: 0.7792
# Epoch 30/50 | Loss: 0.2314 | F1-Macro: 0.7562
# Epoch 40/50 | Loss: 0.2498 | F1-Macro: 0.7602
# Epoch 50/50 | Loss: 0.2575 | F1-Macro: 0.7633
# ✓ WCE best F1-Macro: 0.7914
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2616 | F1-Macro: 0.7934
# Epoch 20/50 | Loss: 0.2486 | F1-Macro: 0.7865
# Epoch 30/50 | Loss: 0.2457 | F1-Macro: 0.7857
# Epoch 40/50 | Loss: 0.2413 | F1-Macro: 0.7881
# Epoch 50/50 | Loss: 0.2421 | F1-Macro: 0.7881
# ✓ PWCE best F1-Macro: 0.7972
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2372 | F1-Macro: 0.7029
# Epoch 20/50 | Loss: 0.2290 | F1-Macro: 0.7470
# Epoch 30/50 | Loss: 0.2267 | F1-Macro: 0.7470
# Epoch 40/50 | Loss: 0.2231 | F1-Macro: 0.8158
# Epoch 50/50 | Loss: 0.2223 | F1-Macro: 0.8161
# ✓ LWCE best F1-Macro: 0.8176
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2500 | F1-Macro: 0.7400
# Epoch 20/50 | Loss: 0.2390 | F1-Macro: 0.8140
# Epoch 30/50 | Loss: 0.2335 | F1-Macro: 0.7904
# Epoch 40/50 | Loss: 0.2315 | F1-Macro: 0.7880
# Epoch 50/50 | Loss: 0.2295 | F1-Macro: 0.8139
# ✓ PLWCE best F1-Macro: 0.8141
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3230 | F1-Macro: 0.7908
# Epoch 20/50 | Loss: 0.3095 | F1-Macro: 0.7853
# Epoch 30/50 | Loss: 0.3029 | F1-Macro: 0.7852
# Epoch 40/50 | Loss: 0.2715 | F1-Macro: 0.8025
# Epoch 50/50 | Loss: 0.2730 | F1-Macro: 0.7915
# ✓ CB best F1-Macro: 0.8025
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/50 | Loss: 0.0583 | F1-Macro: 0.7077
# Epoch 20/50 | Loss: 0.0571 | F1-Macro: 0.7594
# Epoch 30/50 | Loss: 0.0544 | F1-Macro: 0.7617
# Epoch 40/50 | Loss: 0.0542 | F1-Macro: 0.7418
# Epoch 50/50 | Loss: 0.0527 | F1-Macro: 0.7461
# ✓ FOCAL best F1-Macro: 0.8147
#
# ─────────────────────────  Seed 3  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2271 | F1-Macro: 0.7060
# Epoch 20/50 | Loss: 0.2228 | F1-Macro: 0.7086
# Epoch 30/50 | Loss: 0.2214 | F1-Macro: 0.7545
# Epoch 40/50 | Loss: 0.2154 | F1-Macro: 0.7466
# Epoch 50/50 | Loss: 0.2141 | F1-Macro: 0.7485
# ✓ CE best F1-Macro: 0.7619
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3013 | F1-Macro: 0.7632
# Epoch 20/50 | Loss: 0.2820 | F1-Macro: 0.7586
# Epoch 30/50 | Loss: 0.2725 | F1-Macro: 0.7542
# Epoch 40/50 | Loss: 0.2694 | F1-Macro: 0.7666
# Epoch 50/50 | Loss: 0.2777 | F1-Macro: 0.7627
# ✓ WCE best F1-Macro: 0.7989
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2646 | F1-Macro: 0.7880
# Epoch 20/50 | Loss: 0.2605 | F1-Macro: 0.7977
# Epoch 30/50 | Loss: 0.2465 | F1-Macro: 0.8065
# Epoch 40/50 | Loss: 0.2395 | F1-Macro: 0.7864
# Epoch 50/50 | Loss: 0.2404 | F1-Macro: 0.8005
# ✓ PWCE best F1-Macro: 0.8091
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2376 | F1-Macro: 0.7446
# Epoch 20/50 | Loss: 0.2289 | F1-Macro: 0.7462
# Epoch 30/50 | Loss: 0.2259 | F1-Macro: 0.8144
# Epoch 40/50 | Loss: 0.2245 | F1-Macro: 0.8151
# Epoch 50/50 | Loss: 0.2225 | F1-Macro: 0.8164
# ✓ LWCE best F1-Macro: 0.8164
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2496 | F1-Macro: 0.7394
# Epoch 20/50 | Loss: 0.2384 | F1-Macro: 0.7998
# Epoch 30/50 | Loss: 0.2327 | F1-Macro: 0.7942
# Epoch 40/50 | Loss: 0.2323 | F1-Macro: 0.8034
# Epoch 50/50 | Loss: 0.2300 | F1-Macro: 0.8019
# ✓ PLWCE best F1-Macro: 0.8086
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3641 | F1-Macro: 0.7954
# Epoch 20/50 | Loss: 0.3226 | F1-Macro: 0.7913
# Epoch 30/50 | Loss: 0.2897 | F1-Macro: 0.7833
# Epoch 40/50 | Loss: 0.2778 | F1-Macro: 0.7918
# Epoch 50/50 | Loss: 0.2764 | F1-Macro: 0.7883
# ✓ CB best F1-Macro: 0.8142
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/50 | Loss: 0.0582 | F1-Macro: 0.7075
# Epoch 20/50 | Loss: 0.0568 | F1-Macro: 0.7556
# Epoch 30/50 | Loss: 0.0542 | F1-Macro: 0.7468
# Epoch 40/50 | Loss: 0.0528 | F1-Macro: 0.7419
# Epoch 50/50 | Loss: 0.0522 | F1-Macro: 0.7420
# ✓ FOCAL best F1-Macro: 0.7567
#
# ─────────────────────────  Seed 4  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2266 | F1-Macro: 0.7017
# Epoch 20/50 | Loss: 0.2195 | F1-Macro: 0.7040
# Epoch 30/50 | Loss: 0.2174 | F1-Macro: 0.7084
# Epoch 40/50 | Loss: 0.2157 | F1-Macro: 0.7101
# Epoch 50/50 | Loss: 0.2137 | F1-Macro: 0.7111
# ✓ CE best F1-Macro: 0.7112
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3451 | F1-Macro: 0.7688
# Epoch 20/50 | Loss: 0.2920 | F1-Macro: 0.7756
# Epoch 30/50 | Loss: 0.2486 | F1-Macro: 0.7650
# Epoch 40/50 | Loss: 0.2618 | F1-Macro: 0.7633
# Epoch 50/50 | Loss: 0.2748 | F1-Macro: 0.7752
# ✓ WCE best F1-Macro: 0.7871
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2611 | F1-Macro: 0.7824
# Epoch 20/50 | Loss: 0.2516 | F1-Macro: 0.7910
# Epoch 30/50 | Loss: 0.2427 | F1-Macro: 0.7914
# Epoch 40/50 | Loss: 0.2437 | F1-Macro: 0.7927
# Epoch 50/50 | Loss: 0.2426 | F1-Macro: 0.7930
# ✓ PWCE best F1-Macro: 0.8015
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2362 | F1-Macro: 0.7460
# Epoch 20/50 | Loss: 0.2325 | F1-Macro: 0.8156
# Epoch 30/50 | Loss: 0.2279 | F1-Macro: 0.8151
# Epoch 40/50 | Loss: 0.2246 | F1-Macro: 0.8246
# Epoch 50/50 | Loss: 0.2228 | F1-Macro: 0.8292
# ✓ LWCE best F1-Macro: 0.8298
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.2511 | F1-Macro: 0.7563
# Epoch 20/50 | Loss: 0.2388 | F1-Macro: 0.7939
# Epoch 30/50 | Loss: 0.2330 | F1-Macro: 0.8190
# Epoch 40/50 | Loss: 0.2320 | F1-Macro: 0.8072
# Epoch 50/50 | Loss: 0.2302 | F1-Macro: 0.8125
# ✓ PLWCE best F1-Macro: 0.8190
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.3413 | F1-Macro: 0.7944
# Epoch 20/50 | Loss: 0.3064 | F1-Macro: 0.7892
# Epoch 30/50 | Loss: 0.2979 | F1-Macro: 0.7916
# Epoch 40/50 | Loss: 0.2887 | F1-Macro: 0.7820
# Epoch 50/50 | Loss: 0.2735 | F1-Macro: 0.7855
# ✓ CB best F1-Macro: 0.7966
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/50 | Loss: 0.0582 | F1-Macro: 0.7008
# Epoch 20/50 | Loss: 0.0565 | F1-Macro: 0.7616
# Epoch 30/50 | Loss: 0.0562 | F1-Macro: 0.7029
# Epoch 40/50 | Loss: 0.0532 | F1-Macro: 0.7424
# Epoch 50/50 | Loss: 0.0523 | F1-Macro: 0.7467
# ✓ FOCAL best F1-Macro: 0.8102
#
# ============================================================
# ✓ Full experiment completed!
# ============================================================

# %%
# Cell 7: Aggregate + Visualize + Save Results
METRIC_KEYS = ['Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Mid_F1', 'Tail_F1', 'Accuracy', 'F1_Weighted']
loss_names  = LOSS_CONFIGS

agg = {}
for ln in loss_names:
    agg[ln] = {}
    for k in METRIC_KEYS:
        vals = [r[k] for r in seed_results[ln]]
        agg[ln][k] = {'mean': float(np.mean(vals)), 'std': float(np.std(vals))}
    per_cls_all = np.array([r['Per_Class_F1'] for r in seed_results[ln]])
    agg[ln]['Per_Class_F1_mean'] = per_cls_all.mean(axis=0).tolist()
    agg[ln]['Per_Class_F1_std']  = per_cls_all.std(axis=0).tolist()

def ms(ln, k): return f"{agg[ln][k]['mean']:.4f}±{agg[ln][k]['std']:.4f}"

print(f"\n{'='*60}\nEXPERIMENT SUMMARY (mean ± std, N={N_SEEDS})\n{'='*60}")
W = 17
print(f"{'Loss':8s}  {'Bal_Acc':>{W}}  {'F1_Macro':>{W}}  {'Head_F1':>{W}}  {'Tail_F1':>{W}}")
for ln in loss_names:
    print(f"{ln:8s}  {ms(ln,'Balanced_Accuracy'):>{W}}  {ms(ln,'F1_Macro'):>{W}}  {ms(ln,'Head_F1'):>{W}}  {ms(ln,'Tail_F1'):>{W}}")

colors = plt.cm.Set2(np.linspace(0, 1, len(loss_names)))
fig, axes = plt.subplots(1, 4, figsize=(18, 5))
fig.suptitle(f'{DATASET_NAME} Results — Loss Comparison (N={N_SEEDS} seeds)', fontsize=13)
for ax, key, title in zip(
    axes,
    ['Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Tail_F1'],
    ['Balanced Accuracy',  'F1 Macro', 'Head F1', 'Tail F1']
):
    means = [agg[ln][key]['mean'] for ln in loss_names]
    stds  = [agg[ln][key]['std']  for ln in loss_names]
    bars  = ax.bar(loss_names, means, color=colors, alpha=0.85)
    ax.errorbar(loss_names, means, yerr=stds,
                fmt='none', color='black', capsize=4, linewidth=1.2)
    ax.set_title(title, fontsize=11)
    ax.set_ylabel('Score')
    ax.set_ylim(0, 1.15)
    ax.grid(True, alpha=0.3, axis='y')
    for bar, m, s in zip(bars, means, stds):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + s + 0.02,
                f'{m:.3f}', ha='center', va='bottom', fontsize=7)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/results_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

per_cls_mat = np.array([agg[ln]['Per_Class_F1_mean'] for ln in loss_names])
fig, ax = plt.subplots(figsize=(max(14, NUM_CLASSES), 4))
im = ax.imshow(per_cls_mat, aspect='auto', cmap='RdYlGn', vmin=0, vmax=1)
ax.set_xticks(range(NUM_CLASSES))
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=7)
ax.set_yticks(range(len(loss_names)))
ax.set_yticklabels([ln.upper() for ln in loss_names])
ax.set_title(f'Per-Class F1 (mean, N={N_SEEDS} seeds)')
plt.colorbar(im, ax=ax, label='F1')
for i in range(len(loss_names)):
    for j in range(NUM_CLASSES):
        ax.text(j, i, f'{per_cls_mat[i,j]:.2f}', ha='center', va='center', fontsize=6)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/per_class_f1_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(14, 4))
epochs_x = np.arange(1, FINAL_EPOCHS + 1)
for ln in loss_names:
    loss_arr = np.array([h['train_loss']   for h in seed_histories[ln]])
    f1_arr   = np.array([h['val_F1_Macro'] for h in seed_histories[ln]])
    for ax, arr in zip(axes, [loss_arr, f1_arr]):
        m, s = arr.mean(axis=0), arr.std(axis=0)
        line, = ax.plot(epochs_x, m, label=ln.upper())
        ax.fill_between(epochs_x, m - s, m + s, alpha=0.15, color=line.get_color())
for ax, title, ylabel in zip(axes,
    ['Training Loss (mean ± std)', 'Validation F1 Macro (mean ± std)'],
    ['Loss', 'F1 Macro']):
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
    ax.legend(fontsize=8); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

fname = DATASET_NAME.lower().replace('-', '').replace(' ', '_')
results_json = {
    'metadata': {
        'dataset':      DATASET_NAME,
        'model':        'MLP (256-128-64, BatchNorm, Dropout=0.3)',
        'num_classes':  NUM_CLASSES,
        'class_names':  CLASS_NAMES,
        'final_epochs': FINAL_EPOCHS,
        'batch_size':   BATCH_SIZE,
        'n_seeds':      N_SEEDS,
        'optuna_best':  optuna_best,
        'class_counts': class_counts,
    },
    'aggregated': agg,
    'per_seed':   {ln: seed_results[ln] for ln in loss_names},
}
with open(f'{RESULTS_DIR}/{fname}_results.json', 'w') as f:
    json.dump(results_json, f, indent=2)
print('✓ Saved JSON')

summary_rows = []
for ln in loss_names:
    row = {'Loss': ln}
    for k in METRIC_KEYS:
        row[f'{k}_mean'] = round(agg[ln][k]['mean'], 4)
        row[f'{k}_std']  = round(agg[ln][k]['std'],  4)
        row[k]           = f"{agg[ln][k]['mean']:.4f}±{agg[ln][k]['std']:.4f}"
    summary_rows.append(row)
summary_df = pd.DataFrame(summary_rows)

per_class_df = pd.DataFrame(
    {ln: agg[ln]['Per_Class_F1_mean'] for ln in loss_names},
    index=CLASS_NAMES
)

raw_rows = []
for ln in loss_names:
    for s, r in enumerate(seed_results[ln]):
        row = {'loss': ln, 'seed': s}
        for k in METRIC_KEYS:
            row[k] = r[k]
        raw_rows.append(row)

with pd.ExcelWriter(f'{RESULTS_DIR}/{fname}_results.xlsx', engine='openpyxl') as writer:
    summary_df.to_excel(writer,   sheet_name='Summary_MeanStd',  index=False)
    per_class_df.to_excel(writer, sheet_name='Per_Class_F1_Mean')
    pd.DataFrame(raw_rows).to_excel(writer, sheet_name='Per_Seed_Raw', index=False)
print('✓ Saved Excel')

print(f"\n{'='*60}\nFINAL SUMMARY (mean ± std, N={N_SEEDS})\n{'='*60}")
disp = ['Loss', 'Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Tail_F1']
print(summary_df[disp].to_string(index=False))
# Out:
# ============================================================
# EXPERIMENT SUMMARY (mean ± std, N=5)
# ============================================================
# Loss                Bal_Acc           F1_Macro            Head_F1            Tail_F1
# ce            0.7173±0.0103      0.7220±0.0138      0.8810±0.0005      0.4289±0.0475
# wce           0.7683±0.0006      0.7601±0.0047      0.8726±0.0130      0.5585±0.0078
# pwce          0.7654±0.0006      0.7716±0.0035      0.8817±0.0010      0.5898±0.0133
# lwce          0.7641±0.0003      0.7846±0.0032      0.8813±0.0003      0.6148±0.0089
# plwce         0.7641±0.0004      0.7754±0.0024      0.8809±0.0006      0.5900±0.0103
# cb            0.7634±0.0007      0.7708±0.0037      0.8784±0.0017      0.5849±0.0137
# focal         0.7570±0.0135      0.7755±0.0193      0.8804±0.0003      0.5943±0.0539
# ✓ Saved JSON
# ✓ Saved Excel
#
# ============================================================
# FINAL SUMMARY (mean ± std, N=5)
# ============================================================
#  Loss Balanced_Accuracy      F1_Macro       Head_F1       Tail_F1
#    ce     0.7173±0.0103 0.7220±0.0138 0.8810±0.0005 0.4289±0.0475
#   wce     0.7683±0.0006 0.7601±0.0047 0.8726±0.0130 0.5585±0.0078
#  pwce     0.7654±0.0006 0.7716±0.0035 0.8817±0.0010 0.5898±0.0133
#  lwce     0.7641±0.0003 0.7846±0.0032 0.8813±0.0003 0.6148±0.0089
# plwce     0.7641±0.0004 0.7754±0.0024 0.8809±0.0006 0.5900±0.0103
#    cb     0.7634±0.0007 0.7708±0.0037 0.8784±0.0017 0.5849±0.0137
# focal     0.7570±0.0135 0.7755±0.0193 0.8804±0.0003 0.5943±0.0539
