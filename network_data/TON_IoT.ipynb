# %% [markdown]
# # TON_IoT Network Intrusion Detection — LWCE Loss Comparison
#
# PyTorch MLP on TON_IoT Network Traffic (10-class: Normal + 9 attack types).
# Comparing 7 loss functions: `ce`, `wce`, `pwce`, `lwce`, `plwce`, `cb`, `focal`.

# %%
# !pip install -q torch torchvision optuna pandas openpyxl scikit-learn kagglehub

import os, sys, gc, json, warnings, importlib.util, glob
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Subset
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score)
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import optuna
from optuna.samplers import GridSampler

warnings.filterwarnings('ignore')

REPO_PATH = '/content/imbalanced-data-LWCE'
if not os.path.exists(REPO_PATH):
    print('Cloning...')
    # !git clone https://github.com/gseungho/imbalanced-data-LWCE.git {REPO_PATH}

get_clf_loss = None
try:
    spec = importlib.util.spec_from_file_location(
        'clf', f'{REPO_PATH}/image_classification/custom_losses.py'
    )
    clf_module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(clf_module)
    get_clf_loss = clf_module.get_clf_loss
    print('✓ Loss functions loaded!')
except Exception as e:
    print(f'Warning: {e}')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# Kaggle dataset ID: 'arnobbhowmik/ton-iot-network-dataset'
# CSV 파일 1개, 44 columns

DATASET_NAME       = 'TON_IoT'
BATCH_SIZE         = 512
FINAL_EPOCHS       = 50
PROXY_EPOCHS       = 10
PROXY_SUBSET_RATIO = 0.20
TARGET_TOTAL       = 300_000
BENIGN_MAX         = 100_000
RESULTS_DIR = '/content/gdrive/MyDrive/imbalanced-data-LWCE/network_data/results/TON_IoT'
os.makedirs(RESULTS_DIR, exist_ok=True)
print(f'Results dir: {RESULTS_DIR}')
# Out:
# ✓ Loss functions loaded!
# Device: cuda
# Results dir: /content/gdrive/MyDrive/imbalanced-data-LWCE/network_data/results/TON_IoT

# %%
def _stratified_subset(df, label_col, target_total, benign_max):
    unique_labels = df[label_col].unique()
    normal_label  = next((l for l in unique_labels
                          if 'normal' in l.lower() or 'benign' in l.lower()), None)
    non_budget    = target_total - (benign_max if normal_label else 0)
    non_total     = (df[label_col] != normal_label).sum() if normal_label else len(df)
    idx_list = []
    for lbl in unique_labels:
        idx = df.index[df[label_col] == lbl].tolist()
        if normal_label and lbl == normal_label:
            take = min(len(idx), benign_max)
        else:
            prop = len(idx) / max(non_total, 1)
            take = max(50, min(len(idx), int(prop * non_budget)))
        idx_list.extend(np.random.choice(idx, min(take, len(idx)), replace=False).tolist())
    return df.loc[idx_list].reset_index(drop=True)


def make_loaders(X_tr, X_val, X_te, y_tr, y_val, y_te, batch_size):
    def ds(X, y):
        return TensorDataset(torch.tensor(X, dtype=torch.float32),
                             torch.tensor(y, dtype=torch.long))
    train_loader = DataLoader(ds(X_tr,  y_tr),  batch_size=batch_size, shuffle=True,  num_workers=0)
    val_loader   = DataLoader(ds(X_val, y_val), batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(ds(X_te,  y_te),  batch_size=batch_size, shuffle=False, num_workers=0)
    return train_loader, val_loader, test_loader

# Cell 1: Load & Preprocess TON_IoT
import kagglehub

def load_toniot():
    print('Downloading TON_IoT...')
    path = kagglehub.dataset_download('arnobbhowmik/ton-iot-network-dataset')
    print(f'Dataset path: {path}')

    csv_files = sorted(glob.glob(f'{path}/**/*.csv', recursive=True))
    if not csv_files:
        raise FileNotFoundError(f'No CSV files found in {path}')
    print(f'Loading {len(csv_files)} CSV file(s)...')
    dfs = []
    for f in csv_files:
        try:
            df_part = pd.read_csv(f, encoding='utf-8', low_memory=False)
        except UnicodeDecodeError:
            df_part = pd.read_csv(f, encoding='latin-1', low_memory=False)
        dfs.append(df_part)
        print(f'  {os.path.basename(f)}: {len(df_part):,} rows')
    df = pd.concat(dfs, axis=0, ignore_index=True)
    print(f'\nTotal rows: {len(df):,}')
    print(f'Columns: {df.columns.tolist()}')

    # TON_IoT 'type' 컬럼: normal, scanning, DoS, DDoS, ransomware, backdoor, injection, MITM, password, XSS
    LABEL_PRIORITY = ['type', 'Type', 'attack_cat', 'Attack_type', 'attack_type',
                      'Label', 'label', 'category', 'attack', 'Attack']
    label_col = None
    for c in LABEL_PRIORITY:
        if c in df.columns:
            label_col = c
            break
    if label_col is None:
        label_col = df.columns[-1]
        print(f'Warning: using last column as label: {label_col!r}')
    print(f'\nUsing label column: {label_col!r}')
    df['label'] = df[label_col].astype(str).str.strip().str.lower()
    print(f'Unique labels ({df["label"].nunique()}): {sorted(df["label"].unique())}')

    feature_cols = [c for c in df.columns if c not in [label_col, 'label']]
    df[feature_cols] = df[feature_cols].replace([np.inf, -np.inf], np.nan)
    before = len(df)
    df = df.dropna(subset=feature_cols)
    print(f'Dropped {before - len(df):,} rows with inf/NaN')
    num_cols = df[feature_cols].select_dtypes(include=[np.number]).columns.tolist()
    print(f'Numeric features: {len(num_cols)}')

    if len(df) > TARGET_TOTAL:
        df_sub = _stratified_subset(df, 'label', TARGET_TOTAL, BENIGN_MAX)
        print(f'Subset size: {len(df_sub):,}')
    else:
        df_sub = df.copy()
        print(f'Using full dataset: {len(df_sub):,} rows')

    le = LabelEncoder()
    df_sub['class'] = le.fit_transform(df_sub['label'])
    class_names_enc = le.classes_.tolist()
    num_cls         = len(class_names_enc)
    print(f'Classes ({num_cls}): {class_names_enc}')

    X = df_sub[num_cols].values.astype(np.float32)
    y = df_sub['class'].values.astype(np.int64)

    X_tr, X_tmp, y_tr, y_tmp = train_test_split(
        X, y, test_size=0.30, stratify=y, random_state=42
    )
    X_val, X_te, y_val, y_te = train_test_split(
        X_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=42
    )
    scaler = StandardScaler()
    X_tr  = scaler.fit_transform(X_tr)
    X_val = scaler.transform(X_val)
    X_te  = scaler.transform(X_te)

    class_counts = [int((y_tr == i).sum()) for i in range(num_cls)]
    input_dim    = X_tr.shape[1]
    print(f'\n✓ Loaded: Train={len(X_tr):,}, Val={len(X_val):,}, Test={len(X_te):,}')
    print(f'Input dim: {input_dim}')
    print('\nClass distribution (train):')
    for i, (name, cnt) in enumerate(zip(class_names_enc, class_counts)):
        pct = cnt / sum(class_counts) * 100
        print(f'  {i:2d} {name:25s}: {cnt:6,d} ({pct:.2f}%)')
    ir = max(class_counts) / max(min(c for c in class_counts if c > 0), 1)
    print(f'Imbalance ratio: {ir:.0f}:1')
    return (X_tr, X_val, X_te, y_tr, y_val, y_te,
            class_counts, input_dim, class_names_enc, num_cls)


(X_tr, X_val, X_te, y_tr, y_val, y_te,
 class_counts, INPUT_DIM, CLASS_NAMES, NUM_CLASSES) = load_toniot()
train_loader, val_loader, test_loader = make_loaders(
    X_tr, X_val, X_te, y_tr, y_val, y_te, BATCH_SIZE
)
# Out:
# Downloading TON_IoT...
# Downloading to /root/.cache/kagglehub/datasets/arnobbhowmik/ton-iot-network-dataset/1.archive...
# 100%|██████████| 1.71M/1.71M [00:00<00:00, 100MB/s]
# Extracting files...
# Dataset path: /root/.cache/kagglehub/datasets/arnobbhowmik/ton-iot-network-dataset/versions/1
# Loading 1 CSV file(s)...
#   train_test_network.csv: 211,043 rows
#
# Total rows: 211,043
# Columns: ['src_ip', 'src_port', 'dst_ip', 'dst_port', 'proto', 'service', 'duration', 'src_bytes', 'dst_bytes', 'conn_state', 'missed_bytes', 'src_pkts', 'src_ip_bytes', 'dst_pkts', 'dst_ip_bytes', 'dns_query', 'dns_qclass', 'dns_qtype', 'dns_rcode', 'dns_AA', 'dns_RD', 'dns_RA', 'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed', 'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth', 'http_method', 'http_uri', 'http_version', 'http_request_body_len', 'http_response_body_len', 'http_status_code', 'http_user_agent', 'http_orig_mime_types', 'http_resp_mime_types', 'weird_name', 'weird_addl', 'weird_notice', 'label', 'type']
#
# Using label column: 'type'
# Unique labels (10): ['backdoor', 'ddos', 'dos', 'injection', 'mitm', 'normal', 'password', 'ransomware', 'scanning', 'xss']
# Dropped 0 rows with inf/NaN
# Numeric features: 16
# Using full dataset: 211,043 rows
# Classes (10): ['backdoor', 'ddos', 'dos', 'injection', 'mitm', 'normal', 'password', 'ransomware', 'scanning', 'xss']
#
# ✓ Loaded: Train=147,730, Val=31,656, Test=31,657
# Input dim: 16
#
# Class distribution (train):
#    0 backdoor                 : 14,000 (9.48%)
#    1 ddos                     : 14,000 (9.48%)
#    2 dos                      : 14,000 (9.48%)
#    3 injection                : 14,000 (9.48%)
#    4 mitm                     :    730 (0.49%)
#    5 normal                   : 35,000 (23.69%)
#    6 password                 : 14,000 (9.48%)
#    7 ransomware               : 14,000 (9.48%)
#    8 scanning                 : 14,000 (9.48%)
#    9 xss                      : 14,000 (9.48%)
# Imbalance ratio: 48:1

# %%
# Cell 2: Class Distribution Visualization
def visualize_distribution(class_counts, class_names, title, save_path):
    counts = np.array(class_counts)
    order  = np.argsort(counts)[::-1]
    q1, q3 = np.percentile(counts, [33, 66])
    colors = ['#2ecc71' if c >= q3 else '#f39c12' if c >= q1 else '#e74c3c'
              for c in counts[order]]
    fig, ax = plt.subplots(figsize=(max(12, len(class_names)), 4))
    ax.bar(range(len(class_names)), counts[order], color=colors, alpha=0.85)
    ax.set_xticks(range(len(class_names)))
    ax.set_xticklabels([class_names[i] for i in order],
                       rotation=45, ha='right', fontsize=8)
    ax.set_yscale('log')
    ax.set_ylabel('# Training Samples (log scale)')
    ax.set_title(f'{title}  —  Green: Head / Orange: Mid / Red: Tail')
    ax.grid(True, alpha=0.3, axis='y')
    for i, c in enumerate(counts[order]):
        ax.text(i, c * 1.5, f'{c:,}', ha='center', va='bottom', fontsize=7)
    plt.tight_layout()
    plt.savefig(save_path, dpi=100, bbox_inches='tight')
    plt.show()
    q1_val, q3_val = np.percentile(counts, [33, 66])
    head = sum(1 for c in counts if c >= q3_val)
    mid  = sum(1 for c in counts if q1_val <= c < q3_val)
    tail = sum(1 for c in counts if c < q1_val)
    print(f'Head (≥{q3_val:.0f}): {head} classes')
    print(f'Mid  ({q1_val:.0f}–{q3_val:.0f}): {mid} classes')
    print(f'Tail (<{q1_val:.0f}): {tail} classes')

visualize_distribution(
    class_counts, CLASS_NAMES,
    f'{DATASET_NAME} Class Distribution',
    f'{RESULTS_DIR}/class_distribution.png'
)
# Out:
# Head (≥14000): 9 classes
# Mid  (14000–14000): 0 classes
# Tail (<14000): 1 classes

# %%
# Cell 3: MLP Model + Evaluation Functions

class MLP(nn.Module):
    def __init__(self, input_dim, num_classes,
                 hidden_dims=(256, 128, 64), dropout=0.3):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_dims:
            layers += [nn.Linear(prev, h), nn.BatchNorm1d(h),
                       nn.ReLU(), nn.Dropout(dropout)]
            prev = h
        layers.append(nn.Linear(prev, num_classes))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)


def build_mlp():
    return MLP(INPUT_DIM, NUM_CLASSES).to(DEVICE)


def compute_metrics(model, loader, class_counts):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for X_b, y_b in loader:
            preds = model(X_b.to(DEVICE)).argmax(dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_b.numpy())
    y_true = np.array(all_labels)
    y_pred = np.array(all_preds)
    labels = list(range(NUM_CLASSES))
    per_f1 = f1_score(y_true, y_pred, average=None, labels=labels, zero_division=0)
    counts = np.array(class_counts)
    q1, q3 = np.percentile(counts, [33, 66])
    head_idx = [i for i in range(NUM_CLASSES) if counts[i] >= q3]
    mid_idx  = [i for i in range(NUM_CLASSES) if q1 <= counts[i] < q3]
    tail_idx = [i for i in range(NUM_CLASSES) if counts[i] < q1]
    return {
        'Accuracy':          float(accuracy_score(y_true, y_pred)),
        'Balanced_Accuracy': float(balanced_accuracy_score(y_true, y_pred)),
        'F1_Macro':          float(f1_score(y_true, y_pred, average='macro',    zero_division=0)),
        'F1_Weighted':       float(f1_score(y_true, y_pred, average='weighted', zero_division=0)),
        'Per_Class_F1':      per_f1.tolist(),
        'Head_F1': float(per_f1[head_idx].mean()) if head_idx else 0.0,
        'Mid_F1':  float(per_f1[mid_idx].mean())  if mid_idx  else 0.0,
        'Tail_F1': float(per_f1[tail_idx].mean()) if tail_idx else 0.0,
    }

print('✓ MLP and evaluation functions defined')
# Out:
# ✓ MLP and evaluation functions defined

# %%
# Cell 4: train_model() — definition only, not executed here

def train_model(loss_name, class_counts, tr_loader, val_loader,
                alpha=1.0, gamma=2.0, epochs=FINAL_EPOCHS):
    model = build_mlp()
    if get_clf_loss is not None:
        criterion = get_clf_loss(loss_name, class_counts, alpha=alpha, gamma=gamma)
    else:
        criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', patience=5, factor=0.5, min_lr=1e-6
    )
    history       = {'train_loss': [], 'val_F1_Macro': []}
    best_F1_Macro = 0.0
    best_state    = None
    print(f"\n{'='*50}\nTraining {loss_name.upper()} (α={alpha:.2f}, γ={gamma:.2f})\n{'='*50}")
    for epoch in range(epochs):
        model.train()
        epoch_loss, n_batches = 0.0, 0
        for X_b, y_b in tr_loader:
            X_b, y_b = X_b.to(DEVICE), y_b.to(DEVICE)
            logits   = model(X_b)
            loss     = criterion(logits, y_b)
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            epoch_loss += loss.item()
            n_batches  += 1
        avg_loss = epoch_loss / max(n_batches, 1)
        history['train_loss'].append(avg_loss)
        metrics  = compute_metrics(model, val_loader, class_counts)
        f1_macro = metrics['F1_Macro']
        history['val_F1_Macro'].append(f1_macro)
        scheduler.step(f1_macro)
        if f1_macro > best_F1_Macro:
            best_F1_Macro = f1_macro
            best_state    = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        if (epoch + 1) % 10 == 0 or epoch == epochs - 1:
            print(f'Epoch {epoch+1:2d}/{epochs} | Loss: {avg_loss:.4f} | F1-Macro: {f1_macro:.4f}')
    if best_state is not None:
        model.load_state_dict({k: v.to(DEVICE) for k, v in best_state.items()})
    print(f'✓ {loss_name.upper()} best F1-Macro: {best_F1_Macro:.4f}')
    return model, history, best_F1_Macro

print('✓ train_model defined (not executed yet)')
# Out:
# ✓ train_model defined (not executed yet)

# %%
# Cell 5: Optuna Hyperparameter Search
optuna.logging.set_verbosity(optuna.logging.WARNING)
os.environ['TQDM_DISABLE'] = '1'

def _make_proxy_loader(ratio=PROXY_SUBSET_RATIO):
    n   = int(len(train_loader.dataset) * ratio)
    idx = np.random.choice(len(train_loader.dataset), n, replace=False)
    return DataLoader(Subset(train_loader.dataset, idx),
                     batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

def _cleanup(model=None):
    if model is not None:
        del model
    gc.collect()
    torch.cuda.empty_cache()

print(f'Optuna search (proxy: {PROXY_EPOCHS} epochs, {PROXY_SUBSET_RATIO*100:.0f}% subset)\n')
optuna_best  = {}
proxy_loader = _make_proxy_loader()

N_PWCE = 20
study_pwce = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'alpha': np.linspace(0.5, 5.0, N_PWCE).tolist()})
)
def obj_pwce(trial):
    alpha = trial.suggest_float('alpha', 0.5, 5.0)
    model, _, score = train_model('pwce', class_counts, proxy_loader, val_loader,
                                  alpha=alpha, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_pwce.optimize(obj_pwce, n_trials=N_PWCE)
best_pwce = study_pwce.best_params
optuna_best['pwce'] = best_pwce
print(f'✓ PWCE  best: alpha={best_pwce["alpha"]:.2f}  (F1-Macro={study_pwce.best_value:.4f})')

N_PLWCE = 20
study_plwce = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'alpha': np.linspace(1.0, 10.0, N_PLWCE).tolist()})
)
def obj_plwce(trial):
    alpha = trial.suggest_float('alpha', 1.0, 10.0)
    model, _, score = train_model('plwce', class_counts, proxy_loader, val_loader,
                                  alpha=alpha, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_plwce.optimize(obj_plwce, n_trials=N_PLWCE)
best_plwce = study_plwce.best_params
optuna_best['plwce'] = best_plwce
print(f'✓ PLWCE best: alpha={best_plwce["alpha"]:.2f}  (F1-Macro={study_plwce.best_value:.4f})')

N_FOCAL = 20
study_focal = optuna.create_study(
    direction='maximize',
    sampler=GridSampler({'gamma': np.linspace(0.5, 5.0, N_FOCAL).tolist()})
)
def obj_focal(trial):
    gamma = trial.suggest_float('gamma', 0.5, 5.0)
    model, _, score = train_model('focal', class_counts, proxy_loader, val_loader,
                                  gamma=gamma, epochs=PROXY_EPOCHS)
    _cleanup(model)
    return score if score is not None else 0.0
study_focal.optimize(obj_focal, n_trials=N_FOCAL)
best_focal = study_focal.best_params
optuna_best['focal'] = best_focal
print(f'✓ FOCAL best: gamma={best_focal["gamma"]:.2f}  (F1-Macro={study_focal.best_value:.4f})')

print(f'\nOptuna Results:\n{json.dumps(optuna_best, indent=2)}')
# Out:
# Optuna search (proxy: 10 epochs, 20% subset)
#
#
# ==================================================
# Training PWCE (α=4.76, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3625 | F1-Macro: 0.1347
# ✓ PWCE best F1-Macro: 0.1512
#
# ==================================================
# Training PWCE (α=0.74, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0681 | F1-Macro: 0.6083
# ✓ PWCE best F1-Macro: 0.6088
#
# ==================================================
# Training PWCE (α=5.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3396 | F1-Macro: 0.0935
# ✓ PWCE best F1-Macro: 0.1612
#
# ==================================================
# Training PWCE (α=2.39, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.6350 | F1-Macro: 0.2527
# ✓ PWCE best F1-Macro: 0.2527
#
# ==================================================
# Training PWCE (α=2.87, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.4284 | F1-Macro: 0.1533
# ✓ PWCE best F1-Macro: 0.2105
#
# ==================================================
# Training PWCE (α=4.53, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.1824 | F1-Macro: 0.1223
# ✓ PWCE best F1-Macro: 0.1936
#
# ==================================================
# Training PWCE (α=1.92, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0525 | F1-Macro: 0.3249
# ✓ PWCE best F1-Macro: 0.3249
#
# ==================================================
# Training PWCE (α=3.58, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.5154 | F1-Macro: 0.1217
# ✓ PWCE best F1-Macro: 0.2289
#
# ==================================================
# Training PWCE (α=1.45, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.2592 | F1-Macro: 0.5064
# ✓ PWCE best F1-Macro: 0.5064
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1603 | F1-Macro: 0.6329
# ✓ PWCE best F1-Macro: 0.6329
#
# ==================================================
# Training PWCE (α=1.68, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1781 | F1-Macro: 0.3827
# ✓ PWCE best F1-Macro: 0.3827
#
# ==================================================
# Training PWCE (α=3.82, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2809 | F1-Macro: 0.0891
# ✓ PWCE best F1-Macro: 0.1473
#
# ==================================================
# Training PWCE (α=2.63, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.6549 | F1-Macro: 0.1428
# ✓ PWCE best F1-Macro: 0.1783
#
# ==================================================
# Training PWCE (α=2.16, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.8697 | F1-Macro: 0.2506
# ✓ PWCE best F1-Macro: 0.2506
#
# ==================================================
# Training PWCE (α=4.29, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2750 | F1-Macro: 0.1171
# ✓ PWCE best F1-Macro: 0.1336
#
# ==================================================
# Training PWCE (α=3.11, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.5048 | F1-Macro: 0.1208
# ✓ PWCE best F1-Macro: 0.1601
#
# ==================================================
# Training PWCE (α=1.21, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.2050 | F1-Macro: 0.5779
# ✓ PWCE best F1-Macro: 0.5974
#
# ==================================================
# Training PWCE (α=0.50, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0014 | F1-Macro: 0.6273
# ✓ PWCE best F1-Macro: 0.6273
#
# ==================================================
# Training PWCE (α=4.05, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.2699 | F1-Macro: 0.1335
# ✓ PWCE best F1-Macro: 0.2014
#
# ==================================================
# Training PWCE (α=3.34, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3615 | F1-Macro: 0.0852
# ✓ PWCE best F1-Macro: 0.1481
# ✓ PWCE  best: alpha=0.97  (F1-Macro=0.6329)
#
# ==================================================
# Training PLWCE (α=9.53, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1850 | F1-Macro: 0.5753
# ✓ PLWCE best F1-Macro: 0.6078
#
# ==================================================
# Training PLWCE (α=1.47, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9604 | F1-Macro: 0.6359
# ✓ PLWCE best F1-Macro: 0.6359
#
# ==================================================
# Training PLWCE (α=10.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.2048 | F1-Macro: 0.6146
# ✓ PLWCE best F1-Macro: 0.6146
#
# ==================================================
# Training PLWCE (α=4.79, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9913 | F1-Macro: 0.6341
# ✓ PLWCE best F1-Macro: 0.6341
#
# ==================================================
# Training PLWCE (α=5.74, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0480 | F1-Macro: 0.6244
# ✓ PLWCE best F1-Macro: 0.6244
#
# ==================================================
# Training PLWCE (α=9.05, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1827 | F1-Macro: 0.6143
# ✓ PLWCE best F1-Macro: 0.6143
#
# ==================================================
# Training PLWCE (α=3.84, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0231 | F1-Macro: 0.6310
# ✓ PLWCE best F1-Macro: 0.6347
#
# ==================================================
# Training PLWCE (α=7.16, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1071 | F1-Macro: 0.5786
# ✓ PLWCE best F1-Macro: 0.5830
#
# ==================================================
# Training PLWCE (α=2.89, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9728 | F1-Macro: 0.5708
# ✓ PLWCE best F1-Macro: 0.5779
#
# ==================================================
# Training PLWCE (α=1.95, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9677 | F1-Macro: 0.6237
# ✓ PLWCE best F1-Macro: 0.6237
#
# ==================================================
# Training PLWCE (α=3.37, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0138 | F1-Macro: 0.5689
# ✓ PLWCE best F1-Macro: 0.5763
#
# ==================================================
# Training PLWCE (α=7.63, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1122 | F1-Macro: 0.5901
# ✓ PLWCE best F1-Macro: 0.6101
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0449 | F1-Macro: 0.6502
# ✓ PLWCE best F1-Macro: 0.6502
#
# ==================================================
# Training PLWCE (α=4.32, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0207 | F1-Macro: 0.6169
# ✓ PLWCE best F1-Macro: 0.6182
#
# ==================================================
# Training PLWCE (α=8.58, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1914 | F1-Macro: 0.6081
# ✓ PLWCE best F1-Macro: 0.6081
#
# ==================================================
# Training PLWCE (α=6.21, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0906 | F1-Macro: 0.5850
# ✓ PLWCE best F1-Macro: 0.6192
#
# ==================================================
# Training PLWCE (α=2.42, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9717 | F1-Macro: 0.5992
# ✓ PLWCE best F1-Macro: 0.5992
#
# ==================================================
# Training PLWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 0.9838 | F1-Macro: 0.6478
# ✓ PLWCE best F1-Macro: 0.6478
#
# ==================================================
# Training PLWCE (α=8.11, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.1436 | F1-Macro: 0.5170
# ✓ PLWCE best F1-Macro: 0.6022
#
# ==================================================
# Training PLWCE (α=6.68, γ=2.00)
# ==================================================
# Epoch 10/10 | Loss: 1.0870 | F1-Macro: 0.6035
# ✓ PLWCE best F1-Macro: 0.6035
# ✓ PLWCE best: alpha=5.26  (F1-Macro=0.6502)
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.76)
# ==================================================
# Epoch 10/10 | Loss: 0.3391 | F1-Macro: 0.5884
# ✓ FOCAL best F1-Macro: 0.6075
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.74)
# ==================================================
# Epoch 10/10 | Loss: 0.7688 | F1-Macro: 0.5961
# ✓ FOCAL best F1-Macro: 0.6022
#
# ==================================================
# Training FOCAL (α=1.00, γ=5.00)
# ==================================================
# Epoch 10/10 | Loss: 0.3302 | F1-Macro: 0.5972
# ✓ FOCAL best F1-Macro: 0.6388
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.39)
# ==================================================
# Epoch 10/10 | Loss: 0.5329 | F1-Macro: 0.6270
# ✓ FOCAL best F1-Macro: 0.6270
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.87)
# ==================================================
# Epoch 10/10 | Loss: 0.4749 | F1-Macro: 0.5405
# ✓ FOCAL best F1-Macro: 0.5682
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.53)
# ==================================================
# Epoch 10/10 | Loss: 0.3448 | F1-Macro: 0.5833
# ✓ FOCAL best F1-Macro: 0.5833
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.92)
# ==================================================
# Epoch 10/10 | Loss: 0.5702 | F1-Macro: 0.5304
# ✓ FOCAL best F1-Macro: 0.5938
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.58)
# ==================================================
# Epoch 10/10 | Loss: 0.4056 | F1-Macro: 0.5881
# ✓ FOCAL best F1-Macro: 0.5933
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.45)
# ==================================================
# Epoch 10/10 | Loss: 0.6395 | F1-Macro: 0.6123
# ✓ FOCAL best F1-Macro: 0.6123
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.97)
# ==================================================
# Epoch 10/10 | Loss: 0.7178 | F1-Macro: 0.5750
# ✓ FOCAL best F1-Macro: 0.5750
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.68)
# ==================================================
# Epoch 10/10 | Loss: 0.5995 | F1-Macro: 0.6301
# ✓ FOCAL best F1-Macro: 0.6301
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.82)
# ==================================================
# Epoch 10/10 | Loss: 0.4021 | F1-Macro: 0.4899
# ✓ FOCAL best F1-Macro: 0.6039
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.63)
# ==================================================
# Epoch 10/10 | Loss: 0.4839 | F1-Macro: 0.6081
# ✓ FOCAL best F1-Macro: 0.6252
#
# ==================================================
# Training FOCAL (α=1.00, γ=2.16)
# ==================================================
# Epoch 10/10 | Loss: 0.5485 | F1-Macro: 0.6133
# ✓ FOCAL best F1-Macro: 0.6133
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.29)
# ==================================================
# Epoch 10/10 | Loss: 0.3722 | F1-Macro: 0.6021
# ✓ FOCAL best F1-Macro: 0.6068
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/10 | Loss: 0.4603 | F1-Macro: 0.6412
# ✓ FOCAL best F1-Macro: 0.6412
#
# ==================================================
# Training FOCAL (α=1.00, γ=1.21)
# ==================================================
# Epoch 10/10 | Loss: 0.6794 | F1-Macro: 0.6053
# ✓ FOCAL best F1-Macro: 0.6053
#
# ==================================================
# Training FOCAL (α=1.00, γ=0.50)
# ==================================================
# Epoch 10/10 | Loss: 0.8222 | F1-Macro: 0.5465
# ✓ FOCAL best F1-Macro: 0.5998
#
# ==================================================
# Training FOCAL (α=1.00, γ=4.05)
# ==================================================
# Epoch 10/10 | Loss: 0.3905 | F1-Macro: 0.6062
# ✓ FOCAL best F1-Macro: 0.6193
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.34)
# ==================================================
# Epoch 10/10 | Loss: 0.4318 | F1-Macro: 0.5755
# ✓ FOCAL best F1-Macro: 0.5953
# ✓ FOCAL best: gamma=3.11  (F1-Macro=0.6412)
#
# Optuna Results:
# {
#   "pwce": {
#     "alpha": 0.9736842105263157
#   },
#   "plwce": {
#     "alpha": 5.263157894736842
#   },
#   "focal": {
#     "gamma": 3.1052631578947367
#   }
# }

# %%
# Cell 6: Full Experiment (N_SEEDS seeds)
import random

N_SEEDS       = 5
LOSS_CONFIGS  = ['ce', 'wce', 'pwce', 'lwce', 'plwce', 'cb', 'focal']
seed_results   = {ln: [] for ln in LOSS_CONFIGS}
seed_histories = {ln: [] for ln in LOSS_CONFIGS}

print(f"\n{'='*60}")
print(f'FULL EXPERIMENT: {FINAL_EPOCHS} epochs × {len(LOSS_CONFIGS)} losses × {N_SEEDS} seeds')
print(f"{'='*60}")

for seed in range(N_SEEDS):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    print(f"\n{'─'*25}  Seed {seed}  {'─'*25}")
    for loss_name in LOSS_CONFIGS:
        alpha = optuna_best.get(loss_name, {}).get('alpha', 1.0)
        gamma = optuna_best.get('focal', {}).get('gamma', 2.0) if loss_name == 'focal' else 2.0
        model, history, _ = train_model(
            loss_name, class_counts, train_loader, val_loader,
            alpha=alpha, gamma=gamma, epochs=FINAL_EPOCHS
        )
        metrics = compute_metrics(model, test_loader, class_counts)
        seed_results[loss_name].append(metrics)
        seed_histories[loss_name].append(history)
        _cleanup(model)

print(f"\n{'='*60}")
print('✓ Full experiment completed!')
print(f"{'='*60}")
# Out:
# ============================================================
# FULL EXPERIMENT: 50 epochs × 7 losses × 5 seeds
# ============================================================
#
# ─────────────────────────  Seed 0  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6558 | F1-Macro: 0.4487
# Epoch 20/50 | Loss: 0.5398 | F1-Macro: 0.5376
# Epoch 30/50 | Loss: 0.4761 | F1-Macro: 0.5239
# Epoch 40/50 | Loss: 0.4533 | F1-Macro: 0.4883
# Epoch 50/50 | Loss: 0.4521 | F1-Macro: 0.4398
# ✓ CE best F1-Macro: 0.7409
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.8116 | F1-Macro: 0.3292
# Epoch 20/50 | Loss: 0.6737 | F1-Macro: 0.3590
# Epoch 30/50 | Loss: 0.6150 | F1-Macro: 0.4976
# Epoch 40/50 | Loss: 0.6064 | F1-Macro: 0.4591
# Epoch 50/50 | Loss: 0.6004 | F1-Macro: 0.5825
# ✓ WCE best F1-Macro: 0.6141
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7886 | F1-Macro: 0.5317
# Epoch 20/50 | Loss: 0.6412 | F1-Macro: 0.5086
# Epoch 30/50 | Loss: 0.5975 | F1-Macro: 0.5911
# Epoch 40/50 | Loss: 0.5798 | F1-Macro: 0.7708
# Epoch 50/50 | Loss: 0.5737 | F1-Macro: 0.3252
# ✓ PWCE best F1-Macro: 0.7708
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6707 | F1-Macro: 0.5973
# Epoch 20/50 | Loss: 0.5702 | F1-Macro: 0.6815
# Epoch 30/50 | Loss: 0.4685 | F1-Macro: 0.3689
# Epoch 40/50 | Loss: 0.4403 | F1-Macro: 0.6455
# Epoch 50/50 | Loss: 0.4216 | F1-Macro: 0.6497
# ✓ LWCE best F1-Macro: 0.7101
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7320 | F1-Macro: 0.5249
# Epoch 20/50 | Loss: 0.6111 | F1-Macro: 0.4219
# Epoch 30/50 | Loss: 0.5752 | F1-Macro: 0.4780
# Epoch 40/50 | Loss: 0.5672 | F1-Macro: 0.4221
# Epoch 50/50 | Loss: 0.5572 | F1-Macro: 0.4926
# ✓ PLWCE best F1-Macro: 0.6741
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7356 | F1-Macro: 0.3788
# Epoch 20/50 | Loss: 0.6200 | F1-Macro: 0.4062
# Epoch 30/50 | Loss: 0.5310 | F1-Macro: 0.3804
# Epoch 40/50 | Loss: 0.4916 | F1-Macro: 0.3417
# Epoch 50/50 | Loss: 0.4818 | F1-Macro: 0.4365
# ✓ CB best F1-Macro: 0.7641
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/50 | Loss: 0.2637 | F1-Macro: 0.4566
# Epoch 20/50 | Loss: 0.1981 | F1-Macro: 0.3971
# Epoch 30/50 | Loss: 0.1808 | F1-Macro: 0.4146
# Epoch 40/50 | Loss: 0.1737 | F1-Macro: 0.3932
# Epoch 50/50 | Loss: 0.1724 | F1-Macro: 0.6320
# ✓ FOCAL best F1-Macro: 0.7291
#
# ─────────────────────────  Seed 1  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6472 | F1-Macro: 0.4241
# Epoch 20/50 | Loss: 0.5605 | F1-Macro: 0.3560
# Epoch 30/50 | Loss: 0.5080 | F1-Macro: 0.5545
# Epoch 40/50 | Loss: 0.4828 | F1-Macro: 0.6244
# Epoch 50/50 | Loss: 0.4780 | F1-Macro: 0.4602
# ✓ CE best F1-Macro: 0.6685
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.8241 | F1-Macro: 0.3619
# Epoch 20/50 | Loss: 0.6411 | F1-Macro: 0.5932
# Epoch 30/50 | Loss: 0.5887 | F1-Macro: 0.5838
# Epoch 40/50 | Loss: 0.5626 | F1-Macro: 0.4660
# Epoch 50/50 | Loss: 0.5120 | F1-Macro: 0.5005
# ✓ WCE best F1-Macro: 0.6899
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7865 | F1-Macro: 0.4577
# Epoch 20/50 | Loss: 0.6778 | F1-Macro: 0.3353
# Epoch 30/50 | Loss: 0.6257 | F1-Macro: 0.4382
# Epoch 40/50 | Loss: 0.6110 | F1-Macro: 0.5581
# Epoch 50/50 | Loss: 0.6122 | F1-Macro: 0.4556
# ✓ PWCE best F1-Macro: 0.7801
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6901 | F1-Macro: 0.4644
# Epoch 20/50 | Loss: 0.5639 | F1-Macro: 0.5419
# Epoch 30/50 | Loss: 0.4886 | F1-Macro: 0.3689
# Epoch 40/50 | Loss: 0.4691 | F1-Macro: 0.3974
# Epoch 50/50 | Loss: 0.4591 | F1-Macro: 0.5712
# ✓ LWCE best F1-Macro: 0.7769
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7375 | F1-Macro: 0.3731
# Epoch 20/50 | Loss: 0.6185 | F1-Macro: 0.6224
# Epoch 30/50 | Loss: 0.5506 | F1-Macro: 0.2655
# Epoch 40/50 | Loss: 0.5243 | F1-Macro: 0.6573
# Epoch 50/50 | Loss: 0.5191 | F1-Macro: 0.3558
# ✓ PLWCE best F1-Macro: 0.7516
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7386 | F1-Macro: 0.4887
# Epoch 20/50 | Loss: 0.6164 | F1-Macro: 0.4905
# Epoch 30/50 | Loss: 0.5698 | F1-Macro: 0.4853
# Epoch 40/50 | Loss: 0.5538 | F1-Macro: 0.5326
# Epoch 50/50 | Loss: 0.5526 | F1-Macro: 0.3544
# ✓ CB best F1-Macro: 0.5944
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/50 | Loss: 0.2675 | F1-Macro: 0.5573
# Epoch 20/50 | Loss: 0.2055 | F1-Macro: 0.4529
# Epoch 30/50 | Loss: 0.1849 | F1-Macro: 0.2782
# Epoch 40/50 | Loss: 0.1773 | F1-Macro: 0.5956
# Epoch 50/50 | Loss: 0.1712 | F1-Macro: 0.4430
# ✓ FOCAL best F1-Macro: 0.5958
#
# ─────────────────────────  Seed 2  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6558 | F1-Macro: 0.4884
# Epoch 20/50 | Loss: 0.5286 | F1-Macro: 0.5446
# Epoch 30/50 | Loss: 0.4791 | F1-Macro: 0.5893
# Epoch 40/50 | Loss: 0.4535 | F1-Macro: 0.6077
# Epoch 50/50 | Loss: 0.4341 | F1-Macro: 0.6257
# ✓ CE best F1-Macro: 0.7774
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.8163 | F1-Macro: 0.5414
# Epoch 20/50 | Loss: 0.6543 | F1-Macro: 0.4364
# Epoch 30/50 | Loss: 0.5859 | F1-Macro: 0.5688
# Epoch 40/50 | Loss: 0.5674 | F1-Macro: 0.4726
# Epoch 50/50 | Loss: 0.5546 | F1-Macro: 0.3672
# ✓ WCE best F1-Macro: 0.6840
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7661 | F1-Macro: 0.3631
# Epoch 20/50 | Loss: 0.6778 | F1-Macro: 0.6427
# Epoch 30/50 | Loss: 0.5978 | F1-Macro: 0.6159
# Epoch 40/50 | Loss: 0.5823 | F1-Macro: 0.5153
# Epoch 50/50 | Loss: 0.5733 | F1-Macro: 0.5080
# ✓ PWCE best F1-Macro: 0.7287
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6629 | F1-Macro: 0.3639
# Epoch 20/50 | Loss: 0.5430 | F1-Macro: 0.4621
# Epoch 30/50 | Loss: 0.4993 | F1-Macro: 0.3085
# Epoch 40/50 | Loss: 0.4821 | F1-Macro: 0.5306
# Epoch 50/50 | Loss: 0.4756 | F1-Macro: 0.0728
# ✓ LWCE best F1-Macro: 0.7081
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7404 | F1-Macro: 0.4731
# Epoch 20/50 | Loss: 0.6135 | F1-Macro: 0.5009
# Epoch 30/50 | Loss: 0.5723 | F1-Macro: 0.4696
# Epoch 40/50 | Loss: 0.5576 | F1-Macro: 0.5200
# Epoch 50/50 | Loss: 0.5522 | F1-Macro: 0.3409
# ✓ PLWCE best F1-Macro: 0.6603
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7333 | F1-Macro: 0.5307
# Epoch 20/50 | Loss: 0.6124 | F1-Macro: 0.6217
# Epoch 30/50 | Loss: 0.5598 | F1-Macro: 0.4901
# Epoch 40/50 | Loss: 0.5446 | F1-Macro: 0.5387
# Epoch 50/50 | Loss: 0.5341 | F1-Macro: 0.6254
# ✓ CB best F1-Macro: 0.7668
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/50 | Loss: 0.2665 | F1-Macro: 0.5785
# Epoch 20/50 | Loss: 0.2012 | F1-Macro: 0.5622
# Epoch 30/50 | Loss: 0.1767 | F1-Macro: 0.6653
# Epoch 40/50 | Loss: 0.1688 | F1-Macro: 0.4723
# Epoch 50/50 | Loss: 0.1683 | F1-Macro: 0.5156
# ✓ FOCAL best F1-Macro: 0.6728
#
# ─────────────────────────  Seed 3  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6722 | F1-Macro: 0.5562
# Epoch 20/50 | Loss: 0.5467 | F1-Macro: 0.4856
# Epoch 30/50 | Loss: 0.4792 | F1-Macro: 0.1629
# Epoch 40/50 | Loss: 0.4552 | F1-Macro: 0.4873
# Epoch 50/50 | Loss: 0.4437 | F1-Macro: 0.5099
# ✓ CE best F1-Macro: 0.6359
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.8005 | F1-Macro: 0.4319
# Epoch 20/50 | Loss: 0.6474 | F1-Macro: 0.5892
# Epoch 30/50 | Loss: 0.5914 | F1-Macro: 0.7454
# Epoch 40/50 | Loss: 0.5541 | F1-Macro: 0.6307
# Epoch 50/50 | Loss: 0.5372 | F1-Macro: 0.3232
# ✓ WCE best F1-Macro: 0.7454
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7803 | F1-Macro: 0.5174
# Epoch 20/50 | Loss: 0.6523 | F1-Macro: 0.4244
# Epoch 30/50 | Loss: 0.6227 | F1-Macro: 0.4785
# Epoch 40/50 | Loss: 0.6092 | F1-Macro: 0.5040
# Epoch 50/50 | Loss: 0.5950 | F1-Macro: 0.4926
# ✓ PWCE best F1-Macro: 0.7124
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6394 | F1-Macro: 0.4990
# Epoch 20/50 | Loss: 0.5343 | F1-Macro: 0.4829
# Epoch 30/50 | Loss: 0.4834 | F1-Macro: 0.5883
# Epoch 40/50 | Loss: 0.4588 | F1-Macro: 0.4749
# Epoch 50/50 | Loss: 0.4471 | F1-Macro: 0.6153
# ✓ LWCE best F1-Macro: 0.6153
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7202 | F1-Macro: 0.3983
# Epoch 20/50 | Loss: 0.6157 | F1-Macro: 0.5713
# Epoch 30/50 | Loss: 0.5693 | F1-Macro: 0.5201
# Epoch 40/50 | Loss: 0.5604 | F1-Macro: 0.5837
# Epoch 50/50 | Loss: 0.5602 | F1-Macro: 0.5880
# ✓ PLWCE best F1-Macro: 0.7327
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7261 | F1-Macro: 0.4133
# Epoch 20/50 | Loss: 0.6206 | F1-Macro: 0.4191
# Epoch 30/50 | Loss: 0.5872 | F1-Macro: 0.5619
# Epoch 40/50 | Loss: 0.5552 | F1-Macro: 0.4395
# Epoch 50/50 | Loss: 0.5408 | F1-Macro: 0.6074
# ✓ CB best F1-Macro: 0.7531
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/50 | Loss: 0.2622 | F1-Macro: 0.4510
# Epoch 20/50 | Loss: 0.1936 | F1-Macro: 0.5366
# Epoch 30/50 | Loss: 0.1784 | F1-Macro: 0.4511
# Epoch 40/50 | Loss: 0.1711 | F1-Macro: 0.5796
# Epoch 50/50 | Loss: 0.1653 | F1-Macro: 0.4545
# ✓ FOCAL best F1-Macro: 0.6540
#
# ─────────────────────────  Seed 4  ─────────────────────────
#
# ==================================================
# Training CE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6577 | F1-Macro: 0.3590
# Epoch 20/50 | Loss: 0.5405 | F1-Macro: 0.4920
# Epoch 30/50 | Loss: 0.4981 | F1-Macro: 0.5078
# Epoch 40/50 | Loss: 0.4791 | F1-Macro: 0.5601
# Epoch 50/50 | Loss: 0.4727 | F1-Macro: 0.5115
# ✓ CE best F1-Macro: 0.6612
#
# ==================================================
# Training WCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7813 | F1-Macro: 0.2768
# Epoch 20/50 | Loss: 0.6719 | F1-Macro: 0.4209
# Epoch 30/50 | Loss: 0.6346 | F1-Macro: 0.6126
# Epoch 40/50 | Loss: 0.5868 | F1-Macro: 0.4985
# Epoch 50/50 | Loss: 0.5383 | F1-Macro: 0.3279
# ✓ WCE best F1-Macro: 0.6265
#
# ==================================================
# Training PWCE (α=0.97, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.8025 | F1-Macro: 0.5398
# Epoch 20/50 | Loss: 0.6360 | F1-Macro: 0.6654
# Epoch 30/50 | Loss: 0.5484 | F1-Macro: 0.4423
# Epoch 40/50 | Loss: 0.5181 | F1-Macro: 0.4563
# Epoch 50/50 | Loss: 0.5033 | F1-Macro: 0.4750
# ✓ PWCE best F1-Macro: 0.6654
#
# ==================================================
# Training LWCE (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.6888 | F1-Macro: 0.5762
# Epoch 20/50 | Loss: 0.5361 | F1-Macro: 0.4978
# Epoch 30/50 | Loss: 0.4778 | F1-Macro: 0.7005
# Epoch 40/50 | Loss: 0.4551 | F1-Macro: 0.5721
# Epoch 50/50 | Loss: 0.4504 | F1-Macro: 0.7458
# ✓ LWCE best F1-Macro: 0.7458
#
# ==================================================
# Training PLWCE (α=5.26, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7202 | F1-Macro: 0.3834
# Epoch 20/50 | Loss: 0.6114 | F1-Macro: 0.5748
# Epoch 30/50 | Loss: 0.5562 | F1-Macro: 0.4393
# Epoch 40/50 | Loss: 0.5331 | F1-Macro: 0.3886
# Epoch 50/50 | Loss: 0.5325 | F1-Macro: 0.4387
# ✓ PLWCE best F1-Macro: 0.7368
#
# ==================================================
# Training CB (α=1.00, γ=2.00)
# ==================================================
# Epoch 10/50 | Loss: 0.7541 | F1-Macro: 0.4937
# Epoch 20/50 | Loss: 0.6205 | F1-Macro: 0.5251
# Epoch 30/50 | Loss: 0.5364 | F1-Macro: 0.4617
# Epoch 40/50 | Loss: 0.4933 | F1-Macro: 0.5564
# Epoch 50/50 | Loss: 0.4569 | F1-Macro: 0.1410
# ✓ CB best F1-Macro: 0.7326
#
# ==================================================
# Training FOCAL (α=1.00, γ=3.11)
# ==================================================
# Epoch 10/50 | Loss: 0.2624 | F1-Macro: 0.6469
# Epoch 20/50 | Loss: 0.2102 | F1-Macro: 0.3921
# Epoch 30/50 | Loss: 0.1913 | F1-Macro: 0.4282
# Epoch 40/50 | Loss: 0.1850 | F1-Macro: 0.4987
# Epoch 50/50 | Loss: 0.1790 | F1-Macro: 0.4736
# ✓ FOCAL best F1-Macro: 0.7758
#
# ============================================================
# ✓ Full experiment completed!
# ============================================================

# %%
# Cell 7: Aggregate + Visualize + Save Results
METRIC_KEYS = ['Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Mid_F1', 'Tail_F1', 'Accuracy', 'F1_Weighted']
loss_names  = LOSS_CONFIGS

agg = {}
for ln in loss_names:
    agg[ln] = {}
    for k in METRIC_KEYS:
        vals = [r[k] for r in seed_results[ln]]
        agg[ln][k] = {'mean': float(np.mean(vals)), 'std': float(np.std(vals))}
    per_cls_all = np.array([r['Per_Class_F1'] for r in seed_results[ln]])
    agg[ln]['Per_Class_F1_mean'] = per_cls_all.mean(axis=0).tolist()
    agg[ln]['Per_Class_F1_std']  = per_cls_all.std(axis=0).tolist()

def ms(ln, k): return f"{agg[ln][k]['mean']:.4f}±{agg[ln][k]['std']:.4f}"

print(f"\n{'='*60}\nEXPERIMENT SUMMARY (mean ± std, N={N_SEEDS})\n{'='*60}")
W = 17
print(f"{'Loss':8s}  {'Bal_Acc':>{W}}  {'F1_Macro':>{W}}  {'Head_F1':>{W}}  {'Tail_F1':>{W}}")
for ln in loss_names:
    print(f"{ln:8s}  {ms(ln,'Balanced_Accuracy'):>{W}}  {ms(ln,'F1_Macro'):>{W}}  {ms(ln,'Head_F1'):>{W}}  {ms(ln,'Tail_F1'):>{W}}")

colors = plt.cm.Set2(np.linspace(0, 1, len(loss_names)))
fig, axes = plt.subplots(1, 4, figsize=(18, 5))
fig.suptitle(f'{DATASET_NAME} Results — Loss Comparison (N={N_SEEDS} seeds)', fontsize=13)
for ax, key, title in zip(
    axes,
    ['Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Tail_F1'],
    ['Balanced Accuracy',  'F1 Macro', 'Head F1', 'Tail F1']
):
    means = [agg[ln][key]['mean'] for ln in loss_names]
    stds  = [agg[ln][key]['std']  for ln in loss_names]
    bars  = ax.bar(loss_names, means, color=colors, alpha=0.85)
    ax.errorbar(loss_names, means, yerr=stds,
                fmt='none', color='black', capsize=4, linewidth=1.2)
    ax.set_title(title, fontsize=11)
    ax.set_ylabel('Score')
    ax.set_ylim(0, 1.15)
    ax.grid(True, alpha=0.3, axis='y')
    for bar, m, s in zip(bars, means, stds):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + s + 0.02,
                f'{m:.3f}', ha='center', va='bottom', fontsize=7)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/results_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

per_cls_mat = np.array([agg[ln]['Per_Class_F1_mean'] for ln in loss_names])
fig, ax = plt.subplots(figsize=(max(14, NUM_CLASSES), 4))
im = ax.imshow(per_cls_mat, aspect='auto', cmap='RdYlGn', vmin=0, vmax=1)
ax.set_xticks(range(NUM_CLASSES))
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=7)
ax.set_yticks(range(len(loss_names)))
ax.set_yticklabels([ln.upper() for ln in loss_names])
ax.set_title(f'Per-Class F1 (mean, N={N_SEEDS} seeds)')
plt.colorbar(im, ax=ax, label='F1')
for i in range(len(loss_names)):
    for j in range(NUM_CLASSES):
        ax.text(j, i, f'{per_cls_mat[i,j]:.2f}', ha='center', va='center', fontsize=6)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/per_class_f1_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(14, 4))
epochs_x = np.arange(1, FINAL_EPOCHS + 1)
for ln in loss_names:
    loss_arr = np.array([h['train_loss']   for h in seed_histories[ln]])
    f1_arr   = np.array([h['val_F1_Macro'] for h in seed_histories[ln]])
    for ax, arr in zip(axes, [loss_arr, f1_arr]):
        m, s = arr.mean(axis=0), arr.std(axis=0)
        line, = ax.plot(epochs_x, m, label=ln.upper())
        ax.fill_between(epochs_x, m - s, m + s, alpha=0.15, color=line.get_color())
for ax, title, ylabel in zip(axes,
    ['Training Loss (mean ± std)', 'Validation F1 Macro (mean ± std)'],
    ['Loss', 'F1 Macro']):
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
    ax.legend(fontsize=8); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR}/training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

fname = DATASET_NAME.lower().replace('-', '').replace(' ', '_')
results_json = {
    'metadata': {
        'dataset':      DATASET_NAME,
        'model':        'MLP (256-128-64, BatchNorm, Dropout=0.3)',
        'num_classes':  NUM_CLASSES,
        'class_names':  CLASS_NAMES,
        'final_epochs': FINAL_EPOCHS,
        'batch_size':   BATCH_SIZE,
        'n_seeds':      N_SEEDS,
        'optuna_best':  optuna_best,
        'class_counts': class_counts,
    },
    'aggregated': agg,
    'per_seed':   {ln: seed_results[ln] for ln in loss_names},
}
with open(f'{RESULTS_DIR}/{fname}_results.json', 'w') as f:
    json.dump(results_json, f, indent=2)
print('✓ Saved JSON')

summary_rows = []
for ln in loss_names:
    row = {'Loss': ln}
    for k in METRIC_KEYS:
        row[f'{k}_mean'] = round(agg[ln][k]['mean'], 4)
        row[f'{k}_std']  = round(agg[ln][k]['std'],  4)
        row[k]           = f"{agg[ln][k]['mean']:.4f}±{agg[ln][k]['std']:.4f}"
    summary_rows.append(row)
summary_df = pd.DataFrame(summary_rows)

per_class_df = pd.DataFrame(
    {ln: agg[ln]['Per_Class_F1_mean'] for ln in loss_names},
    index=CLASS_NAMES
)

raw_rows = []
for ln in loss_names:
    for s, r in enumerate(seed_results[ln]):
        row = {'loss': ln, 'seed': s}
        for k in METRIC_KEYS:
            row[k] = r[k]
        raw_rows.append(row)

with pd.ExcelWriter(f'{RESULTS_DIR}/{fname}_results.xlsx', engine='openpyxl') as writer:
    summary_df.to_excel(writer,   sheet_name='Summary_MeanStd',  index=False)
    per_class_df.to_excel(writer, sheet_name='Per_Class_F1_Mean')
    pd.DataFrame(raw_rows).to_excel(writer, sheet_name='Per_Seed_Raw', index=False)
print('✓ Saved Excel')

print(f"\n{'='*60}\nFINAL SUMMARY (mean ± std, N={N_SEEDS})\n{'='*60}")
disp = ['Loss', 'Balanced_Accuracy', 'F1_Macro', 'Head_F1', 'Tail_F1']
print(summary_df[disp].to_string(index=False))
# Out:
# ============================================================
# EXPERIMENT SUMMARY (mean ± std, N=5)
# ============================================================
# Loss                Bal_Acc           F1_Macro            Head_F1            Tail_F1
# ce            0.6902±0.0505      0.6940±0.0522      0.7543±0.0554      0.1511±0.0571
# wce           0.7447±0.0450      0.6720±0.0469      0.7305±0.0480      0.1461±0.0453
# pwce          0.8002±0.0399      0.7302±0.0403      0.7908±0.0405      0.1850±0.0536
# lwce          0.7178±0.0649      0.7082±0.0562      0.7478±0.0591      0.3516±0.0525
# plwce         0.7708±0.0388      0.7093±0.0359      0.7590±0.0386      0.2617±0.0638
# cb            0.7846±0.0579      0.7216±0.0633      0.7764±0.0651      0.2277±0.0551
# focal         0.6853±0.0530      0.6813±0.0601      0.7354±0.0601      0.1947±0.1052
# ✓ Saved JSON
# ✓ Saved Excel
#
# ============================================================
# FINAL SUMMARY (mean ± std, N=5)
# ============================================================
#  Loss Balanced_Accuracy      F1_Macro       Head_F1       Tail_F1
#    ce     0.6902±0.0505 0.6940±0.0522 0.7543±0.0554 0.1511±0.0571
#   wce     0.7447±0.0450 0.6720±0.0469 0.7305±0.0480 0.1461±0.0453
#  pwce     0.8002±0.0399 0.7302±0.0403 0.7908±0.0405 0.1850±0.0536
#  lwce     0.7178±0.0649 0.7082±0.0562 0.7478±0.0591 0.3516±0.0525
# plwce     0.7708±0.0388 0.7093±0.0359 0.7590±0.0386 0.2617±0.0638
#    cb     0.7846±0.0579 0.7216±0.0633 0.7764±0.0651 0.2277±0.0551
# focal     0.6853±0.0530 0.6813±0.0601 0.7354±0.0601 0.1947±0.1052
